# %% [markdown]
# # ChatGPT API: Few-Shot Binary Text Classification

# %% [markdown]
# ## The Association for Computational Linguistics
# ## WASSA 2023 Shared Task on Multi-Label and Multi-Class Emotion Classification on Code-Mixed Text Messages
# See more details [here](https://codalab.lisn.upsaclay.fr/competitions/10864#learn_the_details)

# %%
import openai
import numpy as np
import pandas as pd
import sklearn
import re, os
import time
import zipfile, pickle
from typing import List
from copy import deepcopy
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, RidgeClassifier, RidgeClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, multilabel_confusion_matrix
from openai.embeddings_utils import cosine_similarity
from tqdm.autonotebook import tqdm
import random
import tiktoken
import backoff
tqdm.pandas()

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 400)
#os.path.join()
# Out:
# /var/folders/vb/p2r9brhx2335cwnww04p9w180000gn/T/ipykernel_38954/495498401.py:19: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
def num_tokens_from_messages(messages, model="gpt-3.5-turbo-0301"):
    '''Return number of tokens used in a list of messages for ChatGPT'''
    try:
        encoding = tiktoken.encoding_for_model(model)
    except KeyError:
        #print("Warning: model not found. Using cl100k_base encoding.")
        encoding = tiktoken.get_encoding("cl100k_base")
    if model == "gpt-3.5-turbo":
        #print("Warning: gpt-3.5-turbo may change over time. Returning num tokens assuming gpt-3.5-turbo-0301.")
        return num_tokens_from_messages(messages, model="gpt-3.5-turbo-0301")
    elif model == "gpt-4":
        #print("Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.")
        return num_tokens_from_messages(messages, model="gpt-4-0314")
    elif model == "gpt-3.5-turbo-0301":
        tokens_per_message = 4  # every message follows <|start|>{role/name}\n{content}<|end|>\n
        tokens_per_name = -1  # if there's a name, the role is omitted
    elif model == "gpt-4-0314":
        tokens_per_message = 3
        tokens_per_name = 1
    else:
        raise NotImplementedError(f"""num_tokens_from_messages() is not implemented for model {model}. See https://github.com/openai/openai-python/blob/main/chatml.md for information on how messages are converted to tokens.""")
    num_tokens = 0
    for message in messages:
        num_tokens += tokens_per_message
        for key, value in message.items():
            num_tokens += len(encoding.encode(value))
            if key == "name":
                num_tokens += tokens_per_name
    num_tokens += 3  # every reply is primed with <|start|>assistant<|message|>
    return num_tokens

# %%
random_state = 47

# %% [markdown]
# # Load and Prepare Data

# %%
file1    = 'data/mcec_train_translated.pkl'
df_train = pd.read_pickle(file1)

file2    = 'data/mcec_dev_translated.pkl'
df_dev   = pd.read_pickle(file2)

file3    = 'data/mcec_test.csv'
df_test  = pd.read_csv(file3)

file4    = 'data/sample_submission/predictions_MCEC.csv'
sample_submission = pd.read_csv(file4)

print(df_train.shape, df_dev.shape, df_test.shape, sample_submission.shape)
# Out:
# (9530, 5) (1191, 12) (1191, 1) (1191, 1)

# %%
df_train['target'] = df_train['emotion'].apply( lambda x: 0 if x=='neutral' else 1 )
df_dev['target']   = df_dev['emotion'].apply( lambda x: 0 if x=='neutral' else 1 )

# %%
print(df_train['emotion'].value_counts(), '\n')
print(df_train['target'].value_counts())
df_train.head()
# Out:
# neutral         3262
# trust           1118
# joy             1022
# optimism         880
# anticipation     832
# disgust          687
# sadness          486
# fear             453
# anger            226
# surprise         199
# love             187
# pessimism        178
# Name: emotion, dtype: int64
#
# 1    6268
# 0    3262
# Name: target, dtype: int64
#                                                 text  emotion  \
# 0  Yes.I am in fyp lab cabin.but fyp presentation...  neutral
# 1           Yar insan ka bcha bn chawliyn na mar :p       joy
# 2  Terai uncle nai kahna hai kai ham nai to bahr ...  disgust
# 3                      Yr ajao I m cming in the club  neutral
# 4  Mje wese Nimra ahmad ka Qur'aan ki aayaat k ba...      joy
#
#                                        translated_hi  \
# 0  Yes.i am in fyp lab cabin.but fyp presentation...
# 1  Dude become a child of a human being, do not die.
# 2     Your Uncle Nai says that we had sent out money
# 3                     YR AJAO I'M Coming in the Club
# 4  Mje wes nimra ahmad ka qur'aan ki aayaat k bar...
#
#                                        translated_ur  \
# 0  Y. Um in Fap Lab Cabin. Butt Fap Presentations...
# 1                 Dude human beings do not die: P: P
# 2  Your Ankali says that we sent out money and wa...
# 3                           Yer organs were the club
# 4  Mje Wese Nimra Ahmad Ka Qur'aan Ki Aayaaat K B...
#
#                                        gpt_embedding  target
# 0  [-0.005477939732372761, -0.01738985814154148, ...       0
# 1  [0.0006696455529890954, -0.006965265609323978,...       1
# 2  [0.021171217784285545, -0.02109299972653389, 0...       1
# 3  [-0.010511564090847969, -0.02738134376704693, ...       0
# 4  [-0.0016743674641475081, -0.021855581551790237...       1

# %%
print(df_dev['emotion'].value_counts(), '\n')
print(df_dev['target'].value_counts())
df_dev.head()
# Out:
# neutral         388
# joy             131
# trust           125
# disgust         113
# optimism        110
# anticipation     94
# sadness          62
# fear             52
# surprise         35
# anger            35
# pessimism        29
# love             17
# Name: emotion, dtype: int64
#
# 1    803
# 0    388
# Name: target, dtype: int64
#                                                 text    emotion  target  \
# 0                        Tension lene ki koi baat ni    neutral       0
# 1        Main ghar punch gya hun or ab spny laga hun    neutral       0
# 2            Nai mje nai mili mail..mene check ki ti  pessimism       1
# 3  Yr us din mai pura din bzy rahe vo mujy awne h...    disgust       1
# 4                Lakin wo abhe dar dar ka chalata ha       fear       1
#
#                                       gtp_translated  \
# 0                   There's no need to take tension.
# 1   I have reached home and now I am going to sleep.
# 2          I didn't receive any mail, I had checked.
# 3  That day, they were busy all day and not givin...
# 4                     But he still walks cautiously.
#
#                                        translated_hi  \
# 0                   There is nothing to take tension
# 1          I have gone home punch and now I am Sapni
# 2                Nai Maje Nai Mile Mail .. I checked
# 3  YR Us Din Mai Pura Din Bzy Rahe Vo Mujy Awne H...
# 4                     But it still moves at the rate
#
#                                        translated_ur  \
# 0                         Any talk of taking tangoes
# 1              I have gone home punch and now dreams
# 2                                Ni Ni Ni Mille Mail
# 3  Yr us din mai pura din bzy rahe vo mujy awne h...
# 4                              But Wu runs the cedar
#
#                                           text_clean  gpt_pred  gpt_pred_num  \
# 0                        Tension lene ki koi baat ni   neutral             1
# 1        Main ghar punch gya hun or ab spny laga hun   neutral             1
# 2          Nai mje nai mili mail .. mene check ki ti   neutral             1
# 3  Yr us din mai pura din bzy rahe vo mujy awne h...  negative             0
# 4                Lakin wo abhe dar dar ka chalata ha   neutral             1
#
#                                      gpt_translated2  \
# 0                          There's no need to worry.
# 1   I have reached home and now I am going to sleep.
# 2      I didn't receive any new mail. I had checked.
# 3  I was busy the whole day on that day, they wer...
# 4       But he still walks with fear and hesitation.
#
#                            gpt_translated2_corrected  \
# 0                          There's no need to worry.
# 1   I have reached home and now I am going to sleep.
# 2      I didn't receive any new mail. I had checked.
# 3  I was busy the whole day on that day, they wer...
# 4       But he still walks with fear and hesitation.
#
#                                        gpt_embedding
# 0  [-0.00021548081713262945, 0.005029499996453524...
# 1  [-0.0010164333507418633, -0.013282055966556072...
# 2  [-0.010691414587199688, -0.01292553823441267, ...
# 3  [0.009936108253896236, -0.016926730051636696, ...
# 4  [0.019262924790382385, -0.0011249196249991655,...

# %%
# light text cleaning (should I use clean regex for better accuracy?)
pad_punct    = re.compile('([^a-zA-Z ]+)')
multi_spaces = re.compile('\s{2,}')
#clean        = re.compile('[^a-zA-Z0-9,.?!\'\s]+')

def clean_text(s):
    s = s.replace('\n', ' ')
    s = pad_punct.sub(r' \1 ', s)
    #s = clean.sub(' ', s)
    s = multi_spaces.sub(' ', s)
    return s.strip()

df_train['text_clean'] = df_train['text'].apply( clean_text )
df_dev['text_clean']   = df_dev['text'].apply( clean_text )
df_test['text_clean']  = df_test['Text'].apply( clean_text )

# %%
# remove overlap with validation sets
val_sets = df_dev['text_clean'].tolist() + df_test['text_clean'].tolist()
print(len(val_sets), len(set(val_sets)))

print(df_train.shape)
df_train = df_train[ ~df_train['text_clean'].isin(val_sets) ]
print(df_train.shape)
# Out:
# 2382 2206
# (9530, 7)
# (8151, 7)

# %%
# remove duplicates from train set
df_train = df_train.drop_duplicates(subset=['text_clean', 'emotion'])
print(df_train.shape)
# Out:
# (6167, 7)

# %% [markdown]
# # ChatGPT API: Few-Shot Classification

# %% [markdown]
# ## Helper functions

# %%
# Using followup questions improves the reponse. but ChatGPT can change its mind too easily sometimes
followup1 = 'Are you sure about that? If yes, output the same category, if no change the category'
followup2 = 'Output only the category and nothing else'
print(followup1)
# Out:
# Are you sure about that? If yes, output the same category, if no change the category

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")
model          = 'gpt-3.5-turbo'
labels_set     = {'emotional', 'neutral'}
clean = re.compile(r'[^a-zA-Z ]+')
multi_spaces = re.compile('\s{2,}')
print(labels_set)
# Out:
# {'emotional', 'neutral'}

# %%
def verify_label(label_):
    '''
       Verify if label_ contains any of the categories
       from the predefined set of labels
    '''
    label_ = clean.sub(' ', label_)
    label_ = multi_spaces.sub(' ', label_).lower().split()
    res    = [i for i in label_ if i in labels_set]
    res    = list(set(res))
    return '/'.join(res) if res else None

# %%
def verify_num_tokens(model, messages):
    '''Check that there is enough tokens available for a ChatGPT repsonse'''
    num_tokens_tiktoken = num_tokens_from_messages(messages, model)
    if num_tokens_tiktoken > 4080:
        print(f'Number of tokens is {num_tokens_tiktoken} which exceeds 4080')        
        return False
    else:
        return True


@backoff.on_exception(backoff.expo, openai.error.RateLimitError, max_time=10)
def get_response(model, messages, temperature=0, max_tokens=None):
    '''Send request, return reponse'''
    response  = openai.ChatCompletion.create(
        model = model,
        messages = messages,
        temperature = temperature,        # range(0,2), the more the less deterministic / focused
        top_p = 1,                        # top probability mass, e.g. 0.1 = only tokens from top 10% proba mass
        n = 1,                            # number of chat completions
        #max_tokens = max_tokens,          # tokens to return
        stream = False,        
        stop=None,                        # sequence to stop generation (new line, end of text, etc.)
        )
    content = response['choices'][0]['message']['content'].strip()
    #num_tokens_api = response['usage']['prompt_tokens']
    return content

# %% [markdown]
# ## Binary approach 1: concatenate random few-shot examples into one long string

# %% [markdown]
# Example prompt:
# ```
# Message: Support has been terrible for 2 weeks...
# Sentiment: Negative
# ###
# Message: I love your API, it is simple and so fast!
# Sentiment: Positive
# ###
# Message: GPT-J has been released 2 months ago.
# Sentiment: Neutral
# ###
# Message: The reactivity of your team has been amazing, thanks!
# Sentiment:
# ```

# %%
# total tokens in training set
messages = [{ 'role': 'user', 'content': ' '.join(df_train['text_clean'].tolist()) }]
total_tokens        = num_tokens_from_messages(messages)
avg_tokens_per_msg  = total_tokens / df_train.shape[0]
msg_per_window_size = 4096 /  avg_tokens_per_msg
print('Total tokens:', total_tokens)
print('Avg tokens per msg:', avg_tokens_per_msg)
print('Avg messages per window size:', msg_per_window_size)
# Out:
# Total tokens: 116049
# Avg tokens per msg: 18.817739581644236
# Avg messages per window size: 217.66695102930657

# %% [markdown]
# Split df into n random chunks to be used as few-shot examples:

# %%
# divide df into n chunks - this allows for 3k to 3.8k tokens per example
n         = 135
key2label = { 0: 'neutral', 1: 'emotional', }
examples  = []
chunks  = [ df_train.sample(frac=1, random_state=random_state).iloc[i:i+n] for i in range(0, df_train.shape[0], n) ]
for ch in chunks:
    example = ''
    for text, target in ch[['text', 'target']].values:
        example += f'Message: {text}.\nCategory: {key2label[target]}.\n####\n'
    examples.append(example)
        
lengths = [ num_tokens_from_messages([{'role':'user', 'content': example} ]) for example in examples ]
print(lengths)
# Out:
# [3472, 3690, 3662, 3346, 3394, 3608, 3630, 3805, 4022, 3726, 3590, 3530, 3729, 3633, 3722, 3633, 3795, 3630, 3613, 3808, 3540, 3380, 3597, 3528, 3697, 3586, 3634, 3586, 3825, 3750, 3782, 3620, 3472, 3519, 3542, 3583, 3794, 3416, 3455, 3977, 3427, 3476, 3302, 3400, 3531, 2424]

# %%
len(lengths)
# Out:
# 46

# %%
print(examples[0])
# Out:
# Message: Yr jtni jldi ml jaye utna acha he....
# Category: emotional.
# ####
# Message: Haha mei kahan se sweet hun :p.
# Category: emotional.
# ####
# Message: Han abi kuch theek hy shop pr ly kr gya tha.
# Category: neutral.
# ####
# Message: I think .. he made his own slides....
# Category: emotional.
# ####
# Message: Plz give me bike keys. I m in office.
# Category: emotional.
# ####
# Message: Teri do Aakhiyaan Wich Dubb Mrya,.
# Category: emotional.
# ####
# Message: Haha ni wo boy ni smjy g q k wo khud boy ho g.
# Category: emotional.
# ####
# Message: Mera Sirf DataStructure Ka Pta Chala Hai. & Your?.
# Category: emotional.
# ####
# Message: Salam Faiza Baaji
# How are you  ...
# Plz take a  good care of urself.
# Aur jo treat meri taraf due hai uska kiya karna hai?  :-).
# Category: emotional.
# ####
# Message: Sir transport dept walay recomendation letter mang rahay han....
# Category: neutral.
# ####
# Message: Yar  Maine fee a hi tak Jamaica nahi krai 2000 fine ho gear hai to fine maaf kra sakta hai.
# Category: neutral.
# ####
# Message: Ok. U already hav the slides and book.
# Category: neutral.
# ####
# Message: Mera ab 7 strt hOna ha.. :).
# Category: emotional.
# ####
# Message: Han half say bhi thori kam hai as compared to uol.
# Category: neutral.
# ####
# Message: Tues ko classes wasey bhi 4 hai i think srf pori class k sath celebrate karengy nd enjoybhi.
# Category: emotional.
# ####
# Message: kha sy betha or kha pr utra?.
# Category: neutral.
# ####
# Message: Oky bro... Best of luck jani for ms.
# Category: emotional.
# ####
# Message: abhi nhi bnani 4:30 se bnana!!.
# Category: neutral.
# ####
# Message: Wait ma uni wapis a raha ho puhanch kr btata ho.
# Category: neutral.
# ####
# Message: Winedt is better than lyx. Now m using winedtDrivinDriving.
# Category: neutral.
# ####
# Message: Time anay pay sab ka pta chl hi jata ha maza to tb ha k time say phlay pta ho sb.
# Category: emotional.
# ####
# Message: Dont worry I m CR . I will adjust u in any group..
# Category: emotional.
# ####
# Message: tu facebook e na open kr.....
# Category: neutral.
# ####
# Message: G g MASHALLAH  pass ho gya.
# Category: emotional.
# ####
# Message: ay meri sheeeooo loat k aja bin tere her matm her khushi adhuri h.
# Category: emotional.
# ####
# Message: Surly i'll cm nd w8ng u.
# Category: emotional.
# ####
# Message: Sir babar ka email id send kro plz.
# Category: emotional.
# ####
# Message: Q k ap k bohat se ase kaam han jo me ne nahi ki'ye..
# Category: emotional.
# ####
# Message: irsa.. roz USB lena bhul jatu hun, kl le ana mene mbyl me copy krni hn cheezen..
# Category: emotional.
# ####
# Message: Em scared yar yh ni hona tha,.
# Category: emotional.
# ####
# Message: mera mood ku kharab ho ga.
# Category: emotional.
# ####
# Message: Han yar kal jana hy zaroor.
# Category: emotional.
# ####
# Message: bhai coal ma c+
# multi ma b+ lag gya ha..
# Category: emotional.
# ####
# Message: Main to khta hun k bna lo mood ab .
# Category: neutral.
# ####
# Message: Or agar kii teri waja sai kholai ga website par acount to os kai aik click ka.5 rs or roz kai 150 .
# Category: neutral.
# ####
# Message: Yr sftwre eng ka scop ziada he ya cs ka.
# Category: neutral.
# ####
# Message: Oka will wait for ur call.
# Category: emotional.
# ####
# Message: Yaar admin officekay samnay abbasi. Jaa rahay hain .
# Category: neutral.
# ####
# Message: First time in life mujy pucit ki credibility par doubt ho rha ha k koi hosh hi nai in ko.
# Category: emotional.
# ####
# Message: Han kya sen ha hstel ka.
# Category: emotional.
# ####
# Message: Pehly apni information jo us din unhun ny puchi age city language etc wo send kr du us k bad jb chahu msg send dr du.
# Category: neutral.
# ####
# Message: HAYE BHT STUDYYYYYY ki AJJJJ tooo.
# Category: neutral.
# ####
# Message: Jani phr me b to hr time he ap se contact krta hn na.
# Category: emotional.
# ####
# Message: Yaar apnay Abba ko masjid chownk roki.... Kajorien unkay hath ghar bhejwadien.... .
# Category: emotional.
# ####
# Message: Hahaha thaik a tn kera shadi karwni wa charater lose wa.
# Category: emotional.
# ####
# Message: Uncle ko bta dena m n Jana hai.
# Category: emotional.
# ####
# Message: Pas koi atm nae hai apke?.
# Category: neutral.
# ####
# Message: to kia side ln tmhry jesi ni.
# Category: neutral.
# ####
# Message: Shit yar ma ny timetable dykha e nai tha ... Mari bht important class hy 2 bjy ma ja raha hun university ...  .
# Category: emotional.
# ####
# Message: Xheikh Fawad Ahmad Hasan Sahi ????? ????.
# Category: neutral.
# ####
# Message: Han ab to tu esa hi boly ga na.
# Category: emotional.
# ####
# Message: Hmmmm yahan b yehi haal pata ha factory baich di.
# Category: emotional.
# ####
# Message: Hellooooo koi hai begam main agya hellooooooooo charta yi khazi? .
# Category: neutral.
# ####
# Message: Meanwhile get ready your system and Skype.
# Category: neutral.
# ####
# Message: Wasy yeh apki food ha :P.
# Category: emotional.
# ####
# Message: Ok I will send it to you in a few minutes.The slides include portions from the given slides aong with lot of additional data collected by me.
# Category: emotional.
# ####
# Message: O sory yar main ny jo baqi msg tmhain send kiye hain wo usko krny thy jo university aye thy sory.
# Category: emotional.
# ####
# Message: Hudi apni trf se likh k send kr alehda alehda ese alhaty jatay.
# Category: neutral.
# ####
# Message: Suree :p bad may phas jaon hain :p.
# Category: emotional.
# ####
# Message: Programning ki assginmt strt.ki ha koa ?.
# Category: emotional.
# ####
# Message: nbeta assingmnt mili hai labmi lambi.
# Category: emotional.
# ####
# Message: To kya hua 2 mint ka kam hai keh do.
# Category: neutral.
# ####
# Message: hahhahahaha apni guarantee py e khany hain bhai :-D :-P .
# Category: emotional.
# ####
# Message: Mtlb ka hamare tarf hamare hostel..
# Category: neutral.
# ####
# Message: Mosam change ki wajah se bukhaar.
# Category: emotional.
# ####
# Message: Hmmm wo to kbi poori nai hui ji khana b khaya.
# Category: emotional.
# ####
# Message: Please find below a bit of a new one.
# Category: neutral.
# ####
# Message: Oye uni me zong k signal ate hain.. ?.
# Category: neutral.
# ####
# Message: Mery to mind ma he nai tha :-(.
# Category: emotional.
# ####
# Message: Tmharay bai hain to karcha lia karo na unka apna gar ha agr to pirr.
# Category: neutral.
# ####
# Message: yar core 2 due tak bhai bna bnaya mily ga aram sy 8 mein acha best.
# Category: neutral.
# ####
# Message: I was a lil busy... bht saray guest though kab say I was waitin for 18th :( sorry for being late.
# Category: emotional.
# ####
# Message: uuuuuu hme bhuuuuUUUl gayeee.... ye sb khaya kese geya tmse.
# Category: emotional.
# ####
# Message: Us per jb 10k tk ho jaye ga to wo withdraw krwa kr or apny pas se 10k dal kr tmhy account bna du ga.
# Category: emotional.
# ####
# Message: Hm tw 13 bachy hai interior k????????.
# Category: neutral.
# ####
# Message: Shayad settings mein koi backup ka chakkar chalana paray ga
# Mainay kabhi iOS sahi tarha use hi nahin kiya
# Kaisay bataon?.
# Category: emotional.
# ####
# Message: Ghar me or koi nai ha is lye muje lazmi jana hu ga..
# Category: emotional.
# ####
# Message: Idhar bhi yehi haal hai...uni mai sale mehnga bht dete hain.
# Category: emotional.
# ####
# Message: Is lia 3:30 tak chuty ho gahy gi.
# Category: emotional.
# ####
# Message: chl phr share kr lty hn. what say.?.
# Category: emotional.
# ####
# Message: Yar tm mere group me hti maza ata :-P.
# Category: emotional.
# ####
# Message: rayaan kah raa hy dado k pass rakhwa dain keyss abi hmm nikaly wy.
# Category: neutral.
# ####
# Message: U r responsible fr it got it.
# Category: neutral.
# ####
# Message: Gas kitni dair k liye khuli the.
# Category: neutral.
# ####
# Message: G abi kia aur ab lhr jane lga hn.
# Category: emotional.
# ####
# Message: Ok mje b kal kr dena phr.
# Category: emotional.
# ####
# Message: hain mjhe adat nh zada dair rukny ki.
# Category: neutral.
# ####
# Message: Mjay smjh ne ara kis k group main jau , to bs iswaja abi kisi group main ne hu.
# Category: emotional.
# ####
# Message: you mean ye shain A rab hmari school friend hai????.
# Category: emotional.
# ####
# Message: U ko pta b sub, phr b keh rhi.
# Category: emotional.
# ####
# Message: Thaik a hun fr ki karna a.
# Category: emotional.
# ####
# Message: You are invited to a small treat by me on the occasion of Getting Elected CR on Monday Venue will be informed later plz confirm your presence by a text or call. ""Dont bring anyone else"".
# Category: emotional.
# ####
# Message: Us ko phr ap kud samja le warna ?.
# Category: emotional.
# ####
# Message: Yr plzz mere liye 2nd row me jaga zaroor rakh lena nd boyz ki taraf wali seat na rakhna plzz! Mje thori si der ho jae gi cx of traffic!,.
# Category: emotional.
# ####
# Message: Han, kaha to h wo ek namuna th, jiske baareek beeni.. Hd t wese :).
# Category: emotional.
# ####
# Message: Hahaha lhr ma tym hta ha ap k liye u knw naa.
# Category: emotional.
# ####
# Message: Tu fikr na kr wo dost hi ha mera .wo dy dy ga jitny ma boloon ga ..
# Category: emotional.
# ####
# Message: Fahad ne baray nmbr maray hein.
# Category: emotional.
# ####
# Message: Haha acha mery sony per keh rhi ho.
# Category: emotional.
# ####
# Message: Gray clor m ha car mamu ne btya ha.
# Category: neutral.
# ####
# Message: Nhe yr brish bht ho rhe m nhe a rha.
# Category: emotional.
# ####
# Message: Yaar me ajau na lab me? .
# Category: neutral.
# ####
# Message: Ni nxt wek se jyn ge :-) new no.ab on kia ha...is lye cntct ni kr sake :-).
# Category: emotional.
# ####
# Message: Thanx jani.Abi tk tu ni lagi
# Kuch peenay ko dil kr rha hau
# Kia peena ha?
# Jani jb bhok lgy to btana
# Q ab kia hwa?.
# Category: emotional.
# ####
# Message: Han umeed ha :-P oka dne hua bta dunga :-P.
# Category: emotional.
# ####
# Message: Have they returned???what is their feedback???.
# Category: emotional.
# ####
# Message: Yar bc tum log late krwao ge .
# Category: emotional.
# ####
# Message: Or eshal kase ha?adeil bhai ksy han.
# Category: neutral.
# ####
# Message: w.a fit bhai ap sunaen. Alhamdullah...achi guzri .Ap ki eid kaisay guzri.
# Category: emotional.
# ####
# Message: Wohi ker rha hun is waqt.12 tk btaunga.light nai a rhi thi subha charging khatam thi laptop ki.
# Category: emotional.
# ####
# Message: Same here.... me bhii Facebook p post aur comment bohat kam krta hon..
# Category: neutral.
# ####
# Message: Matlb k sindh k under ata ha wo area..
# Category: neutral.
# ####
# Message: complier download k liye link de,.
# Category: emotional.
# ####
# Message: Hahahaha... ap ne Monday ko uni ana hai ?.
# Category: emotional.
# ####
# Message: han han flat to mil jyn gy...wahan...area acha ha...lkn bc comsats dkhen tw aaaa k....pind ma ha...fctry area ma.
# Category: emotional.
# ####
# Message: nhi ji itni easy bi nhi ha!!.
# Category: emotional.
# ####
# Message: Han mujy to itnaaa gussa hi awta he thora thora to awta hi nai he.
# Category: emotional.
# ####
# Message: pupho trf axa hn dawat par.
# Category: neutral.
# ####
# Message: meri d ma enrol ho gyi ha ccn.
# Category: neutral.
# ####
# Message: mam iqra sy pouch ly na.
# Category: emotional.
# ####
# Message: saly location change ki ja rahy ho parking ki trf a registr ly kr.
# Category: emotional.
# ####
# Message: Yaar maliya or Hajra ko kiya tha basit nay baki ghar ghar..... .
# Category: neutral.
# ####
# Message: Ok bro wo maire pass hai thnks.
# Category: neutral.
# ####
# Message: Thanks for infom but i cant , becouz kal mn ne choti marni hy muje nankana sahib jana hy or mondy ko wapisi ho gi. .
# Category: emotional.
# ####
# Message: Hahahha keh deta hoon sbko fikr na kr.
# Category: emotional.
# ####
# Message: Msg pary bgr del nahi ho sakta..
# Category: neutral.
# ####
# Message: kch nh. khtm kr is bt ko. ye chlta rhy ga sari zindgi.
# Category: emotional.
# ####
# Message: Vo keh rai hay sir ko call kr k kaho k humne krwai hn assignmnts.
# Category: emotional.
# ####
# Message: Fazan main 10 minute bad guliana say niklon ga. .
# Category: emotional.
# ####
# Message: Main ne to kuch kaha he ni yr.
# Category: emotional.
# ####
# Message: Main chutti hi nahi karti :-D.
# Category: emotional.
# ####
# Message: O yar tm nay kn sa jok aj sunaia tha. .
# Category: neutral.
# ####
# Message: Sir ne pprs nai check kiye..me abi udr e thi.
# Category: neutral.
# ####
# Message: Tu b usy msg kar dy k mery 7 a jaye.
# Category: neutral.
# ####
# Message: Oye apna roll no btaa PUCIT ka,,,.
# Category: emotional.
# ####

# %%
def classify_text_few_shot(prompt_):
    '''Classify text_ using prompt_ and ChatGPT API'''
        
    # compose messages and check num_tokens
    messages = [
            #{ "role": "system", "content": "You are a very accurate text classifier.", },
            { "role": "user", "content": prompt_, },
            ]
    if not verify_num_tokens(model, messages): return None
    label_    = get_response(model, messages)
    old_label = label_
    label_    = verify_label(label_)        # get just the category if response is too long
        
    # if label not found in response text - second, extended chat
    if label_ is None:
        messages += [
            { "role": "assistant", "content": old_label, },
            { "role": "user", "content": followup1, }
            ]        
        label_    = get_response(model, messages)        
        old_label = label_
        label_    = verify_label(label_)        # get just the category if response is too long
            
    return label_ if label_ is not None else old_label

# %%
start  = time.time()
#res    = dict()
count1 = 0
count2 = 0
for t in df_dev['text'].tolist():
    if t in res:
        continue
    if count2 >= len(examples):
        count2 = 0
    prompt = examples[ count2 ] + f'\nMessage: {t}.\nCategory:'
    count2 += 1
    try:
        res[ t ] = classify_text_few_shot(prompt)
    except openai.error.RateLimitError:
        print(f'\nText: {t}.\nRate limit error\n')
    except Exception as e:
        print(f'\nText: {t}\nError: {e}\n')
                
    count1 += 1    
    if count1 % 10 == 0:
        print(f'Processing text {count1}; example {count2-1}')
        with open('data/res.pkl', 'wb') as f:
            pickle.dump(res, f, protocol=pickle.HIGHEST_PROTOCOL)
                        
        
elapsed = (time.time() - start)/60
print(f'\nTime elapsed {round(elapsed, 4)} min')
#file = 'data/res.pkl'
#with open(file, 'rb') as f:
#    res2 = pickle.load(handle)
# Out:
# Time elapsed 0.1439 min

# %%
df_dev['gpt_pred'] = df_dev['text'].map( res )
df_dev['gpt_pred'].value_counts()
# Out:
# emotional                                        715
# neutral                                          470
# Yes, I'm sure. The category is motivational.       1
# Yes, I'm sure. The category is offensive.          1
# Yes, I'm sure. The category is inappropriate.      1
# Yes, the category is offensive.                    1
# Yes, I'm sure. The category is positive.           1
# Yes, I'm sure. The category is humorous.           1
# Name: gpt_pred, dtype: int64

# %%
df_dev['gpt_pred_binary'] = df_dev['gpt_pred'].apply( lambda x: 0 if x=='neutral' else 1 )
df_dev['gpt_pred_binary'].value_counts()
# Out:
# 1    721
# 0    470
# Name: gpt_pred_binary, dtype: int64

# %%
y_dev      = df_dev['target'].values
y_dev_pred = df_dev['gpt_pred_binary'].values
print( classification_report( y_dev, y_dev_pred, digits=4 ) )
# Out:
#               precision    recall  f1-score   support
#
#            0     0.4723    0.5722    0.5175       388
#            1     0.7698    0.6912    0.7283       803
#
#     accuracy                         0.6524      1191
#    macro avg     0.6211    0.6317    0.6229      1191
# weighted avg     0.6729    0.6524    0.6597      1191

# %% [markdown]
# ## Approach 2: concatenate random few shot examples using the ChatGPT chat mode

# %% [markdown]
# Split df into n random chunks to be used as few-shot examples:

# %%
# divide df into n chunks - this allows for 3k to 3.8k tokens per example
n          = 100
key2label = { 0: 'neutral', 1: 'emotional', }
examples  = []
chunks = [ df_train.sample(frac=1, random_state=random_state).iloc[i:i+n] for i in range(0, df_train.shape[0], n) ]
for ch in chunks:
    example = []
    for text, target in ch[['text', 'target']].values:
        example += [
            { "role": "user", "content": f'Text: {text}', },
            { "role": "assistant", "content": f'Category: {key2label[target]}', }
        ]
    examples.append(example)
        
lengths = [ num_tokens_from_messages(example) for example in examples ]
print(len(lengths))
print(lengths)
# Out:
# 62
# [3276, 3350, 3424, 3554, 3229, 3153, 3260, 3487, 3364, 3365, 3709, 3762, 3400, 3387, 3440, 3391, 3424, 3327, 3546, 3423, 3485, 3484, 3543, 3349, 3414, 3372, 3678, 3399, 3280, 3190, 3375, 3327, 3381, 3527, 3335, 3470, 3383, 3494, 3549, 3502, 3499, 3454, 3436, 3261, 3324, 3311, 3371, 3271, 3568, 3475, 3273, 3229, 3403, 3705, 3208, 3326, 3203, 3250, 3275, 3261, 3324, 2279]

# %%
# how one example looks
examples[2]
# Out:
# [{'role': 'user', 'content': 'Text: kiu yar a jana mza aye ga!?'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Mujhe msg oe msg kr rhi he'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: ma ab tk k exprnce k hwly sy bl rha hn. life to pta h bht h'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': "Text: Mene jannat k pattay prh liya atlast :')"},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Or wo achi khaasi intelligent t tbi itni okhi paheli boojh li t :P'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Tm logo  ka off ho gaixa hn aur tm ne rida ki pic daekane the . ...,'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Pehla name mera e c jinna nu pta a,par mainu ki pta a, ae mainu nai pts'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: Mjy sirf y mila h A jao g'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Pata chl gya ha. Zaheer ha. Medicine ka keh rha ha.'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: Hy , chali gai ho hostal se ya abi nai'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Tm e calculate kr k bta do'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: QqHahahahaha shabash practice karo .... Aglay 3 saal yehi karna hai :P '},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: yr band h wo log publicty krny k lyai jarhy hain sary lake city wapda town etc'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: hahhahahahha :-D to dua e ulti krr lia krro :-P '},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Evening hours mei soo gaya tha :p '},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: subha me ne ami k sath bank jana h free ho kr clg chalo ga tery sath ..'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Ramzan me ai this call us ki LST time mar GI phir WO shayad,'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Phr kehti Allah hfz mne kaha Allah hfz'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: pti job to dekhi jay ge lekin study b jari rkh '},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: yar pakistan st.\nka kuch kr k tou nai ana tha ?? quiz tou ni aj ?'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Hawn naa n mera group partner ak larka hy he is damn genius par uska half face khrab hy right side scary birth marks n wo cosmo plastic surgery krwata hy tw he cant speak properly \npar uska artifical inteligence ka project yar im amazed to c neuro computer pay banaya usny human brain feelings k change hony sy clours on paper change n abstract art banta'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Is waqt bechare idps sub se zyada tap rhe hn ge halat dekh k'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: R u coming to my office?'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: jaldi aa na phr khana b khana ha'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Nhi you have to come to us'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: Mje laga ap bizi ho jo reply nai kiyaa'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Yar plz ksi tarha cancel karwa .'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Ok . i am ready for that'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Oye, madam aa gai class mein?'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: To n ana kb tk h'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Sir comment likh b phir mitta dia k mazeed depress kia kerna khud ko b orr tujhe b.'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Ok. Wasy monday off hota hy papa ka !'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: Nai pgl..koi masla nai..le ao usko..'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Swift aap Sargodha sae hi lae gi'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Usna aik status dia hai iss liye poch rha tha ...\nKhair kia krta rha Sara din?'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: OK mae internet sae dekh or btata hoon'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Wo waly msg send krny hain ... Jo khud type kiye tum ny .. Okay. '},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Mushaf part 1,part 2 yun kr k dhoonda Kar nq'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: end pa hassan k baad roll no and section mention krna ha'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: Gari ghr hai le lain key usmain se'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Um.. Yar i remember kbi tha wahan pay.. Let me google branches'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Ohh asha g yeh bi ha '},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Tusday tk krde\nMain kiwain wadawan jado agla bnda ae kh dawe k mra ae kam aik bnda 35 ch kr rya a pr tu mra pakka expert aen islai de rya wan ab 45 pe mana hai wo b last main tje 2500 dedunga tu bs krwa ache bnde se'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Faizi bhaaaaaaaaaiiii  oa wo kashif ka bhateja tera bara fan, dp p comments hain j :>'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Haaan yeh b haii abb mamla to bht nazuk haiii'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Usy kahun ga cs dept p oficial kam ha hum dunu ko is lye aj hum ni asakty..'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: rizwan aya h???\nusy keh dain zra puch ay ik mint\nOth jay to msg karin.  Istri lani !!\nHstl nikal jna h ab yhan sy tm logo ny???\nOayyy umer ka rzlt???'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: oee aur kitna late?? :P ... Chal agar mai jaa raha hoon GA kal to tujhay Bata doon GA...'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Hahaha ghar se nikal de ga tera aba . 3 ki krni ha mene birthday wese b :D '},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Kahen b yr dor chlty hn'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Ramadan k baad se meri waist 34 ho gae he\nPhle 32 ti'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Han kiya hoa koi masla ha kiya'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Shukar wali bat he \t Nankana sb. Colege ka bhai hspitl ha . Tamardari k ly rokna. '},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: No you have to tell them'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Then u hav to purchase a cd for anti virus. Uss mein free b hotay hain kafi. Try that baby'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Hahaha \nWo jese bht Moti thi na experience tha usay'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Itni jaldi ja ke kya kare gye. '},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Meray whatsapp pe apka yehi number aa ra hai... doosra nahin'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: Skyp py ao phr btata hu'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Us k bd din me bhr h0tel me khana kha lyn gye f0trus phr lyn gy'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: To dare kis bat ke :D'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Han parha ha muje buht pasand ha :),'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: I have reached the destination,  I repeat I have reached the destination,  where are you?'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Ok ma b dost k gar hn, abi. . . . Jhor town me. . . . Wo bike pe muje site pe chor dy ga tb bhai ko bula ln ga'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: I phne ke sheshkay lea ja raha ha :-P '},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Office. Aur zaheer log keh rhy hn chalain biliard khelny'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: Yr nechay hi parha howa ha'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: tn to serious e ly gya ha chwl.....mazak kr raha tha yar....ahhaha ro naaa'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Insha Allah aaj majlis ho gi'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: InshALLAH baba kal uni bhejti. Wo kia bt kar k ayn?'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Han vo thk he lkn aj ke date mn vo aw jane chahiye.. '},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Oh okay chalo IA thek hojayega :)'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Main apni presentation send kr ryan,tusi v send kro'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Pta nai. Us ka ab reply be nai a rha.'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Wese kis k sath jane ka irada ha :-P'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Yar programming ka lecture sahi Tara pata nai chalta'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: ghnty tk aa jana ghr mama bula rhi hn'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Matlab rubber ka hard pipe, zahir hai koi pipe chahiye cylinderical stiff jisay roller bnaen friction wala'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: OK abhi mae perh raha hoon Raat ko Bta doon ga'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: nae yrrr halat se tang aa gai hn'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Ok. Me Wahin Admin K Samane Hun.'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Yr jb paper deny jao ge to result pata kr k ana mera'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Han bs fridy ko clash ata ha.'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Lkn mujy to khana b bnana awta he vo b achee wala..'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Sae he bai tu jan gia guru ko'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: hahaha...itna h pyar rha to gya ku ni...isld..saly ghar bth k bten h sb krty han'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Yar is lye ke kal me ghar ja rha hu'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: N ambreen ko F de dia ha sir atif ne:@@'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Mam mehwish ik mail hmari management ko b kar deti to shayad un ko kuch hosh a jata'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Daikh lo yr \nBta daina na.'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Usy kahye ga bt kry mjhse jb ay to'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': "Text: Han but helpless hu na thats why you couldn't hear my voice :D "},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Han yar 1 bachi teray bhai ko bri pyari lagi..'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Hahahaahah bohat mushkil say  ....mai nay ir maahi nay milkay maza aagaya '},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user',
#   'content': 'Text: Salam\nG achhaa ho gaya.\nits the best I could deliver'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: khiar woooo tooo khd ko fkhti ni'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Teri marzi ha. Me to tmhy 100 bar keh chuka hn'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: han mri sis k achay e agye mrkx'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: Yr wo thek rhe ga hmare kam k mtabik'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: O nahi yar mujy tu nahi mila wo'},
#  {'role': 'assistant', 'content': 'Category: neutral'}]

# %%
def classify_text_few_shot2(text_, messages_, model):
    '''Classify text_ using prompt_ and ChatGPT API'''
    messages_ = deepcopy(messages_)
    messages_ += [
        { "role": "user", "content": f'Text: {text_}', },
    ]
    if not verify_num_tokens(model, messages_): return None
    label_    = get_response(model, messages_)
    old_label = label_
    label_    = verify_label(label_)        # get just the category if response is too long
        
    # if label not found in response text - second, extended chat
    if label_ is None:
        messages_ += [
            { "role": "assistant", "content": old_label, },
            { "role": "user", "content": followup1, }
            ]        
        label_    = get_response(model, messages_)
        old_label = label_
        label_    = verify_label(label_)        # get just the category if response is too long
            
    return label_ if label_ is not None else old_label

# %%
start  = time.time()
res    = dict()
count1 = 0
count2 = 0
for t in df_dev['text'].tolist():
    if t in res:
        continue
    if count2 >= len(examples):
        count2 = 0
    messages = examples[ count2 ]
    count2 += 1
    try:
        res[ t ] = classify_text_few_shot2(t, messages, model)
    except openai.error.RateLimitError:
        print(f'\nText: {t}.\nRate limit error\n')
    except Exception as e:
        print(f'\nText: {t}\nError: {e}\n')
                
    count1 += 1    
    if count1 % 10 == 0:
        print(f'Processing text {count1}; example {count2-1}. Time elapsed: {round((time.time()-start)/60, 4)} min')
        with open('data/res.pkl', 'wb') as f:
            pickle.dump(res, f, protocol=pickle.HIGHEST_PROTOCOL)
                        
        
elapsed = (time.time() - start)/60
print(f'\nTime elapsed {round(elapsed, 4)} min')
#file = 'data/res.pkl'
#with open(file, 'rb') as f:
#    res2 = pickle.load(handle)
# Out:
# Processing text 10; example 9. Time elapsed: 0.2034 min
# Processing text 20; example 19. Time elapsed: 0.3919 min
# Processing text 30; example 29. Time elapsed: 0.5834 min
# Processing text 40; example 39. Time elapsed: 0.7687 min
# Processing text 50; example 49. Time elapsed: 0.9588 min
# Processing text 60; example 59. Time elapsed: 1.1971 min
# Processing text 70; example 7. Time elapsed: 1.409 min
# Processing text 80; example 17. Time elapsed: 1.6186 min
# Processing text 90; example 27. Time elapsed: 1.8049 min
# Processing text 100; example 37. Time elapsed: 2.0017 min
# Processing text 110; example 47. Time elapsed: 2.1894 min
# Processing text 120; example 57. Time elapsed: 2.3815 min
# Processing text 130; example 5. Time elapsed: 2.5695 min
# Processing text 140; example 15. Time elapsed: 2.7638 min
# Processing text 150; example 25. Time elapsed: 2.9498 min
# Processing text 160; example 35. Time elapsed: 3.1631 min
# Processing text 170; example 45. Time elapsed: 3.4141 min
# Processing text 180; example 55. Time elapsed: 3.7554 min
# Processing text 190; example 3. Time elapsed: 3.9429 min
# Processing text 200; example 13. Time elapsed: 4.1376 min
# Processing text 210; example 23. Time elapsed: 4.3597 min
# Processing text 220; example 33. Time elapsed: 4.5491 min
# Processing text 230; example 43. Time elapsed: 4.7338 min
# Processing text 240; example 53. Time elapsed: 4.9189 min
# Processing text 250; example 1. Time elapsed: 5.1207 min
# Processing text 260; example 11. Time elapsed: 5.3034 min
# Processing text 270; example 21. Time elapsed: 5.5149 min
# Processing text 280; example 31. Time elapsed: 5.7044 min
# Processing text 290; example 41. Time elapsed: 5.887 min
# Processing text 300; example 51. Time elapsed: 6.0798 min
# Processing text 310; example 61. Time elapsed: 6.2642 min
# Processing text 320; example 9. Time elapsed: 6.4502 min
# Processing text 330; example 19. Time elapsed: 6.6506 min
# Processing text 340; example 29. Time elapsed: 6.8541 min
# Processing text 350; example 39. Time elapsed: 7.0395 min
# Processing text 360; example 49. Time elapsed: 7.3332 min
# Processing text 370; example 59. Time elapsed: 7.513 min
# Processing text 380; example 7. Time elapsed: 7.7275 min
# Processing text 390; example 17. Time elapsed: 7.9173 min
# Processing text 400; example 27. Time elapsed: 8.1013 min
# Processing text 410; example 37. Time elapsed: 8.3013 min
# Processing text 420; example 47. Time elapsed: 8.4898 min
# Processing text 430; example 57. Time elapsed: 8.6901 min
# Processing text 440; example 5. Time elapsed: 8.8708 min
# Processing text 450; example 15. Time elapsed: 9.0604 min
# Processing text 460; example 25. Time elapsed: 9.2481 min
# Processing text 470; example 35. Time elapsed: 9.4376 min
# Processing text 480; example 45. Time elapsed: 9.6999 min
# Processing text 490; example 55. Time elapsed: 9.9496 min
# Processing text 500; example 3. Time elapsed: 10.1271 min
# Processing text 510; example 13. Time elapsed: 10.3138 min
# Processing text 520; example 23. Time elapsed: 10.4932 min
# Processing text 530; example 33. Time elapsed: 10.6941 min
# Processing text 540; example 43. Time elapsed: 10.9104 min
# Processing text 550; example 53. Time elapsed: 11.0887 min
# Processing text 560; example 1. Time elapsed: 11.3887 min
# Processing text 570; example 11. Time elapsed: 11.5906 min
# Processing text 580; example 21. Time elapsed: 11.7825 min
# Processing text 590; example 31. Time elapsed: 11.9647 min
# Processing text 600; example 41. Time elapsed: 12.1648 min
# Processing text 610; example 51. Time elapsed: 12.3709 min
# Processing text 620; example 61. Time elapsed: 12.5809 min
# Processing text 630; example 9. Time elapsed: 12.7758 min
# Processing text 640; example 19. Time elapsed: 12.9753 min
# Processing text 650; example 29. Time elapsed: 13.1708 min
# Processing text 660; example 39. Time elapsed: 13.3694 min
# Processing text 670; example 49. Time elapsed: 13.5778 min
# Processing text 680; example 59. Time elapsed: 13.8767 min
# Processing text 690; example 7. Time elapsed: 14.0882 min
# Processing text 700; example 17. Time elapsed: 14.4176 min
# Processing text 710; example 27. Time elapsed: 14.6036 min
# Processing text 720; example 37. Time elapsed: 14.7964 min
# Processing text 730; example 47. Time elapsed: 14.9822 min
# Processing text 740; example 57. Time elapsed: 15.2726 min
# Processing text 750; example 5. Time elapsed: 15.4664 min
# Processing text 760; example 15. Time elapsed: 15.6515 min
# Processing text 770; example 25. Time elapsed: 15.8409 min
# Processing text 780; example 35. Time elapsed: 16.0297 min
# Processing text 790; example 45. Time elapsed: 16.2164 min
# Processing text 800; example 55. Time elapsed: 16.4052 min
# Processing text 810; example 3. Time elapsed: 16.6231 min
# Processing text 820; example 13. Time elapsed: 16.82 min
# Processing text 830; example 23. Time elapsed: 17.0112 min
# Processing text 840; example 33. Time elapsed: 17.2032 min
# Processing text 850; example 43. Time elapsed: 17.417 min
# Processing text 860; example 53. Time elapsed: 17.6284 min
# Processing text 870; example 1. Time elapsed: 17.8139 min
# Processing text 880; example 11. Time elapsed: 18.0128 min
# Processing text 890; example 21. Time elapsed: 18.2005 min
# Processing text 900; example 31. Time elapsed: 18.3885 min
# Processing text 910; example 41. Time elapsed: 18.584 min
# Processing text 920; example 51. Time elapsed: 18.8016 min
# Processing text 930; example 61. Time elapsed: 18.9982 min
# Processing text 940; example 9. Time elapsed: 19.1818 min
# Processing text 950; example 19. Time elapsed: 19.3821 min
# Processing text 960; example 29. Time elapsed: 19.571 min
# Processing text 970; example 39. Time elapsed: 19.7593 min
# Processing text 980; example 49. Time elapsed: 19.9419 min
# Processing text 990; example 59. Time elapsed: 20.1515 min
# Processing text 1000; example 7. Time elapsed: 20.3524 min
# Processing text 1010; example 17. Time elapsed: 20.5718 min
# Processing text 1020; example 27. Time elapsed: 20.7815 min
# Processing text 1030; example 37. Time elapsed: 20.9784 min
# Processing text 1040; example 47. Time elapsed: 21.1688 min
# Processing text 1050; example 57. Time elapsed: 21.3682 min
# Processing text 1060; example 5. Time elapsed: 21.5567 min
# Processing text 1070; example 15. Time elapsed: 21.7432 min
# Processing text 1080; example 25. Time elapsed: 21.939 min
# Processing text 1090; example 35. Time elapsed: 22.1368 min
# Processing text 1100; example 45. Time elapsed: 22.4372 min
# Processing text 1110; example 55. Time elapsed: 22.6254 min
# Processing text 1120; example 3. Time elapsed: 22.8275 min
# Processing text 1130; example 13. Time elapsed: 23.0142 min
# Processing text 1140; example 23. Time elapsed: 23.2053 min
# Processing text 1150; example 33. Time elapsed: 23.4134 min
#
# Time elapsed 23.4134 min

# %%
df_dev['gpt_pred'] = df_dev['text'].map( res )
df_dev['gpt_pred'].value_counts()
# Out:
# emotional                                       808
# neutral                                         382
# Yes, I'm sure. The category is motivational.      1
# Name: gpt_pred, dtype: int64

# %%
df_dev['gpt_pred_binary'] = df_dev['gpt_pred'].apply( lambda x: 0 if x=='neutral' else 1 )
df_dev['gpt_pred_binary'].value_counts()
# Out:
# 1    809
# 0    382
# Name: gpt_pred_binary, dtype: int64

# %%
y_dev      = df_dev['target'].values
y_dev_pred = df_dev['gpt_pred_binary'].values
print( classification_report( y_dev, y_dev_pred, digits=4 ) )
# Out:
#               precision    recall  f1-score   support
#
#            0     0.4895    0.4820    0.4857       388
#            1     0.7515    0.7572    0.7543       803
#
#     accuracy                         0.6675      1191
#    macro avg     0.6205    0.6196    0.6200      1191
# weighted avg     0.6662    0.6675    0.6668      1191

# %% [markdown]
# ## Approach 3: same as 2, but use the most similar examples

# %%
model          = 'gpt-3.5-turbo'
key2label      = { 0: 'neutral', 1: 'emotional', }
embedding_type = 'gpt_embedding'

# %%
# find top_n closest df_train embeddings for each df_dev embedding
def batch_cosine(embedding_, df, top_n=100):
    df['similarity'] = df[embedding_type].apply(lambda x: cosine_similarity(x, embedding_))
    return df.sort_values(by='similarity', ascending=False).head(top_n)['text'].tolist()

df_train_copy = df_train.copy()
start = time.time()
res   = dict()
count = 0
for t, e in df_dev[['text', embedding_type]].values:
    if t in res:
        continue
    res[ t ] = batch_cosine( e, df_train_copy, top_n=100, )
    count += 1
    if count % 10 == 0:
        print(f'Processing text {count}. Time elapsed: {round((time.time()-start)/60, 4)} min')
        with open('data/res.pkl', 'wb') as f:
            pickle.dump(res, f, protocol=pickle.HIGHEST_PROTOCOL)
                        
elapsed = (time.time() - start)/60
print(f'\nTime elapsed {round(elapsed, 4)} min')
# Out:
# Processing text 10. Time elapsed: 0.3077 min
# Processing text 20. Time elapsed: 0.615 min
# Processing text 30. Time elapsed: 0.9206 min
# Processing text 40. Time elapsed: 1.2267 min
# Processing text 50. Time elapsed: 1.534 min
# Processing text 60. Time elapsed: 1.8395 min
# Processing text 70. Time elapsed: 2.1474 min
# Processing text 80. Time elapsed: 2.4545 min
# Processing text 90. Time elapsed: 2.76 min
# Processing text 100. Time elapsed: 3.0655 min
# Processing text 110. Time elapsed: 3.3716 min
# Processing text 120. Time elapsed: 3.68 min
# Processing text 130. Time elapsed: 3.9857 min
# Processing text 140. Time elapsed: 4.2943 min
# Processing text 150. Time elapsed: 4.6008 min
# Processing text 160. Time elapsed: 4.9075 min
# Processing text 170. Time elapsed: 5.2152 min
# Processing text 180. Time elapsed: 5.5222 min
# Processing text 190. Time elapsed: 5.8275 min
# Processing text 200. Time elapsed: 6.1335 min
# Processing text 210. Time elapsed: 6.4391 min
# Processing text 220. Time elapsed: 6.7438 min
# Processing text 230. Time elapsed: 7.0495 min
# Processing text 240. Time elapsed: 7.3559 min
# Processing text 250. Time elapsed: 7.6624 min
# Processing text 260. Time elapsed: 7.9662 min
# Processing text 270. Time elapsed: 8.2722 min
# Processing text 280. Time elapsed: 8.5805 min
# Processing text 290. Time elapsed: 8.887 min
# Processing text 300. Time elapsed: 9.1932 min
# Processing text 310. Time elapsed: 9.4983 min
# Processing text 320. Time elapsed: 9.8024 min
# Processing text 330. Time elapsed: 10.1088 min
# Processing text 340. Time elapsed: 10.4157 min
# Processing text 350. Time elapsed: 10.7205 min
# Processing text 360. Time elapsed: 11.0273 min
# Processing text 370. Time elapsed: 11.3336 min
# Processing text 380. Time elapsed: 11.6413 min
# Processing text 390. Time elapsed: 11.9465 min
# Processing text 400. Time elapsed: 12.2533 min
# Processing text 410. Time elapsed: 12.5611 min
# Processing text 420. Time elapsed: 12.8675 min
# Processing text 430. Time elapsed: 13.1734 min
# Processing text 440. Time elapsed: 13.4798 min
# Processing text 450. Time elapsed: 13.7876 min
# Processing text 460. Time elapsed: 14.0916 min
# Processing text 470. Time elapsed: 14.3999 min
# Processing text 480. Time elapsed: 14.7047 min
# Processing text 490. Time elapsed: 15.0097 min
# Processing text 500. Time elapsed: 15.3173 min
# Processing text 510. Time elapsed: 15.6238 min
# Processing text 520. Time elapsed: 15.9306 min
# Processing text 530. Time elapsed: 16.2381 min
# Processing text 540. Time elapsed: 16.5421 min
# Processing text 550. Time elapsed: 16.8492 min
# Processing text 560. Time elapsed: 17.1571 min
# Processing text 570. Time elapsed: 17.4642 min
# Processing text 580. Time elapsed: 17.7698 min
# Processing text 590. Time elapsed: 18.0761 min
# Processing text 600. Time elapsed: 18.3847 min
# Processing text 610. Time elapsed: 18.6919 min
# Processing text 620. Time elapsed: 18.9982 min
# Processing text 630. Time elapsed: 19.3028 min
# Processing text 640. Time elapsed: 19.6096 min
# Processing text 650. Time elapsed: 19.916 min
# Processing text 660. Time elapsed: 20.2243 min
# Processing text 670. Time elapsed: 20.5297 min
# Processing text 680. Time elapsed: 20.8355 min
# Processing text 690. Time elapsed: 21.1429 min
# Processing text 700. Time elapsed: 21.4482 min
# Processing text 710. Time elapsed: 21.7545 min
# Processing text 720. Time elapsed: 22.0624 min
# Processing text 730. Time elapsed: 22.3691 min
# Processing text 740. Time elapsed: 22.6768 min
# Processing text 750. Time elapsed: 22.9803 min
# Processing text 760. Time elapsed: 23.2845 min
# Processing text 770. Time elapsed: 23.5896 min
# Processing text 780. Time elapsed: 23.8954 min
# Processing text 790. Time elapsed: 24.2006 min
# Processing text 800. Time elapsed: 24.5079 min
# Processing text 810. Time elapsed: 24.8163 min
# Processing text 820. Time elapsed: 25.124 min
# Processing text 830. Time elapsed: 25.4304 min
# Processing text 840. Time elapsed: 25.7377 min
# Processing text 850. Time elapsed: 26.0457 min
# Processing text 860. Time elapsed: 26.3534 min
# Processing text 870. Time elapsed: 26.659 min
# Processing text 880. Time elapsed: 26.9653 min
# Processing text 890. Time elapsed: 27.2721 min
# Processing text 900. Time elapsed: 27.5785 min
# Processing text 910. Time elapsed: 27.8849 min
# Processing text 920. Time elapsed: 28.1904 min
# Processing text 930. Time elapsed: 28.4959 min
# Processing text 940. Time elapsed: 28.8032 min
# Processing text 950. Time elapsed: 29.108 min
# Processing text 960. Time elapsed: 29.4142 min
# Processing text 970. Time elapsed: 29.721 min
# Processing text 980. Time elapsed: 30.0287 min
# Processing text 990. Time elapsed: 30.3336 min
# Processing text 1000. Time elapsed: 30.6392 min
# Processing text 1010. Time elapsed: 30.9445 min
# Processing text 1020. Time elapsed: 31.2502 min
# Processing text 1030. Time elapsed: 31.554 min
# Processing text 1040. Time elapsed: 31.8592 min
# Processing text 1050. Time elapsed: 32.1677 min
# Processing text 1060. Time elapsed: 32.4741 min
# Processing text 1070. Time elapsed: 32.779 min
# Processing text 1080. Time elapsed: 33.0857 min
# Processing text 1090. Time elapsed: 33.3919 min
# Processing text 1100. Time elapsed: 33.6953 min
# Processing text 1110. Time elapsed: 34.0022 min
# Processing text 1120. Time elapsed: 34.3095 min
# Processing text 1130. Time elapsed: 34.6162 min
# Processing text 1140. Time elapsed: 34.9208 min
# Processing text 1150. Time elapsed: 35.2262 min
#
# Time elapsed 35.2263 min

# %%
df_dev['closest_texts'] = df_dev['text'].map( res )
print(df_dev.isna().sum())

file = 'data/df_dev_100_closest_GptEmbeddings.pkl'
df_dev.to_pickle(file)
# Out:
# text                         0
# emotion                      0
# target                       0
# gtp_translated               0
# translated_hi                0
# translated_ur                0
# text_clean                   0
# gpt_pred                     0
# gpt_pred_num                 0
# gpt_translated2              0
# gpt_translated2_corrected    0
# gpt_embedding                0
# closest_texts                0
# dtype: int64

# %%
file = 'data/df_dev_100_closest_GptEmbeddings.pkl'
df_dev = pd.read_pickle(file)
df_dev.head()
# Out:
#                                                 text    emotion  target  \
# 0                        Tension lene ki koi baat ni    neutral       0
# 1        Main ghar punch gya hun or ab spny laga hun    neutral       0
# 2            Nai mje nai mili mail..mene check ki ti  pessimism       1
# 3  Yr us din mai pura din bzy rahe vo mujy awne h...    disgust       1
# 4                Lakin wo abhe dar dar ka chalata ha       fear       1
#
#                                       gtp_translated  \
# 0                   There's no need to take tension.
# 1   I have reached home and now I am going to sleep.
# 2          I didn't receive any mail, I had checked.
# 3  That day, they were busy all day and not givin...
# 4                     But he still walks cautiously.
#
#                                        translated_hi  \
# 0                   There is nothing to take tension
# 1          I have gone home punch and now I am Sapni
# 2                Nai Maje Nai Mile Mail .. I checked
# 3  YR Us Din Mai Pura Din Bzy Rahe Vo Mujy Awne H...
# 4                     But it still moves at the rate
#
#                                        translated_ur  \
# 0                         Any talk of taking tangoes
# 1              I have gone home punch and now dreams
# 2                                Ni Ni Ni Mille Mail
# 3  Yr us din mai pura din bzy rahe vo mujy awne h...
# 4                              But Wu runs the cedar
#
#                                           text_clean  gpt_pred  gpt_pred_num  \
# 0                        Tension lene ki koi baat ni   neutral             1
# 1        Main ghar punch gya hun or ab spny laga hun   neutral             1
# 2          Nai mje nai mili mail .. mene check ki ti   neutral             1
# 3  Yr us din mai pura din bzy rahe vo mujy awne h...  negative             0
# 4                Lakin wo abhe dar dar ka chalata ha   neutral             1
#
#                                      gpt_translated2  \
# 0                          There's no need to worry.
# 1   I have reached home and now I am going to sleep.
# 2      I didn't receive any new mail. I had checked.
# 3  I was busy the whole day on that day, they wer...
# 4       But he still walks with fear and hesitation.
#
#                            gpt_translated2_corrected  \
# 0                          There's no need to worry.
# 1   I have reached home and now I am going to sleep.
# 2      I didn't receive any new mail. I had checked.
# 3  I was busy the whole day on that day, they wer...
# 4       But he still walks with fear and hesitation.
#
#                                        gpt_embedding  \
# 0  [-0.00021548081713262945, 0.005029499996453524...
# 1  [-0.0010164333507418633, -0.013282055966556072...
# 2  [-0.010691414587199688, -0.01292553823441267, ...
# 3  [0.009936108253896236, -0.016926730051636696, ...
# 4  [0.019262924790382385, -0.0011249196249991655,...
#
#                                        closest_texts
# 0  [Tension na lo hi jaw ga, O nahi yar tension n...
# 1  [Main tu ghar hi rehta main kahan ja skta, Ghr...
# 2  [Nai yar mje to pta e nai kuch, Mjhe tu ni lgt...
# 3  [Yr masla pta kia ha. Yad ha tm log us din upa...
# 4  [Pata nahe ab kahan chala gea hai kamina, Han ...

# %%
df_dev['target'].value_counts()
# Out:
# 1    803
# 0    388
# Name: target, dtype: int64

# %%
# verify
for i, j in df_dev[['text', 'closest_texts']].values[:10]:
    print(i)
    print(j, '\n')
    #closest = '\n'.join(j)
    #print(f'ORIGINAL TRANSLATED TEXT:\n{i}')
    #print(f"CLOSEST TRANSLATIONS:\n{closest}\n")
# Out:
# Tension lene ki koi baat ni
# ['Tension na lo hi jaw ga', 'O nahi yar tension na lu', 'Pata hai mujahi par no tension', 'Han yar kam ho jai ga parha dn yar tension na lai', 'Na bro us din koi duty nahe hai. Bus kal ki hai baki phir kisi din ki koi tension nahe', 'Haan mian koi baat bni ? ', 'Result ki tension lag gayi hay', 'Tu rehney dey tension na lay ka', 'Han kiya hoa koi masla ha kiya', 'Mje tensn hti hai na kisi ka kaam na hoo', 'Hn ho jna ha arrange..\nTension na ly..', 'Yar telha sy meri baat krwa day', 'Or sunain janab koi ni tazi', 'G ap bolain kiya baat h. ', 'Nai tm tensi0n na lo mene n0te kia tha lectr me tmy likhwa dn g,', 'Pta ni de ga zaror tension na le', 'Shukar mama ko bht tension thi', 'Han main kr dun ga tun tension mat ly yar', 'Tujy koi aur kaam nhi ha bhai ', 'Haan yawr koi kam ni mila tha henna ? ', 'Jani tujey aik baat batai thi', 'Ijtami faisla hua or koi meeting ni hui', 'Thek se has lo,.thn mood ho to baat kr lena', 'Hahaha koi nai ho jaye ga', 'O ja yar tension na ly', 'Ni ... Uski koi call ni ai aor ma abhi utha hn', 'Larki b to koi sahe mle', 'Q ja koi nahi skta yar', 'Idhar koi janai walai rahtai hai kai nai', 'Me bell denay lga hu teri', 'Net daikhna zara wire tu nai hili.aaj a nai raha', 'Ho jai ga cover my love Aaap tension na lain.,', 'Nae ic topic pe meri us se koi bat nae hui', 'Itna bara b koi iasue ni ab. ', 'Nai yar koi masla nai..tm relax hoke apni treatments krao :D', 'Nahi yr Asi koi bat nahi', 'Ni yr tu bta kya kia. ', 'Phone per baat kr lo. Wo kahi nikl na jai', 'koi bhi nhi aisa jo baich rha hu', 'Han bas nikalne lge hyn tk kahan ha ? ', 'Paki baat ha ? Fb lar mil e ni rahi ', 'G sir kab tak pohnch rahe hen', 'O ja main koi nahi jana', 'Hamza ki baat ker rha hun.', 'Mene to seriously haar maan li t. Mje lga th k mere zada attempts krne se ye masla hogya :(\nMera dil kr rha h tumhare sth walk krke baat krne ka :P such mein me itni tensed t, ab behtr hun tumse or huma se baat krke.', 'Lagta ha koi sasta nasha karnay lag gya ha', 'Han jb milein gy tb to batein krein gy e..tm tension na lo ;)', 'Phr agy ki baat krty hain .', 'Nahi its ok assignment abhi mila hai nahi tension subko phly say hi hogye groups ki ', 'Nai yaar tu pagal ha kiya', 'Tm se baat k lye jaag lu ga thori dair', 'Ok. To relax rahain.IA kaam ho jaey ga yaar. Mujhay khud tension h. Barish nay sub kaam kharab kr k rakh diay hn. Galiyan pani say overflow ker rhi hn banda kaheen ja bhi nhi sakta ', 'Koi pata naiii wo larkay ne laptop nai lena abiii ', 'Me kia kheir ni lagdi aj ap ap ', 'Ghar me or koi nai ha is lye muje lazmi jana hu ga.', 'Phr gand dikha rha he kabhi kam ni aya', 'Neelam vally dne karo kabhi nai gae sab ko kya msg abhi dne karo baad mao masla hta', 'To jan bhoj k nae aya', 'Ni bhai main ny aisey koi bat ni ki', 'Thorai din pehlai tak nasir ka phone aya hn ga tujhai hana', 'Pas koi atm nae hai apke?', 'Tera dola sola dekh kr dar Lagta ha', 'Yar ton koi riksha ly k a ja.', 'Dial kar no dibara aik baar shayad ho gai,', 'Yaar pohnchty pohnchtay time lag gya', 'Gt poilt ka lye nahi aye kya', 'Tu ja kr baat krwa dy bs meri', 'Dil ni kr raha kse ku b moo laganae ka. Mood ni teak.', 'Teri na ne wo kr den', 'Me b bore ho jati hon', 'Ni koi tention ni he wesay keh raha hun zara 2sron ki dua bari jaldi lagti he na is liye.', 'Pata kr us sy k ha koi leny wala?', 'Wase tra shehr itna b acha ni', 'Message pe baat kro jo krni hai 1 se phle bahir nai a skta', 'Mene puch h sub se koi b ni ara ', 'yr koi asteefa ni dena kisi ne', 'Thoray dino ki to baat ha . . . . . . Phr jitni dil ha baat kr lena', 'Ni yr me keh ra hu k tu us se keh', 'Ok sir g . . . . . . Aur koi nai tazi', 'Han jiii kabi kabi hojata hai', 'Dekh kai ru aik din nai aya or kia kia ho gia', 'Oho ab aesi bhi koi baat nahi thi or kal ki baat ko ajj nahi sochna chaiye forget it', 'Yeh galat hogaya na abhi aesi koi baat nahi honi chaiye thi lekin khair hai usay cake ka tu nahi pata na', 'Nai room ki bat to nai ki', "Mere to L lag gye...pta nae kya bn'na hai", 'Thkk ho jaon ga bas neend p ...
#
# Main ghar punch gya hun or ab spny laga hun
# ['Main tu ghar hi rehta main kahan ja skta', 'Ghr ja rahy ho kahan punch gi ho', 'Nai yr wo ma abi lhr punch a hu', 'Main tu gari main beth gya hun but wo pagal ka bacha chala hi nahi raha', 'G han sb apne ghar hty hn', 'Hum ghar sy chal pary hn', 'Nai main to gar main bhor ho jatta hn ', 'G abi kia aur ab lhr jane lga hn', 'G boy ma kafi  dar ka punch gya hu', 'Tk hai ab aaye na aaye\nMain ja raha hn', 'Main b thek hu, kya karae ho?', 'Is main main kahan say a gaya hun hmm', 'Mein ghousia chk pe khara hon', 'Gari ghr hai le lain key usmain se', 'ab mere ghr waly na smjain bat ko tou me kia kru', 'G sir kab tak pohnch rahe hen', 'Yar uni punch ke btata hu.', 'Nai abhi abhi ghussa hun kaha to he', 'Ruk ja abhi cng dalwa rahy hain', 'Ghar say niklo gay to msg kar dena', 'Ok ma abi thori dair tk gar say nikal rha hn to muj say main road say pakar lena sath gar walo ny hona ha', 'Ghar hn aj paper hai uski tayri kar raha hn. Khariyat?', 'Me trreray ghar k bhr hu', 'Half hur tk lhr pohnch jaon ga ', 'My ap k ghr aa rha ho abi ap ghr hy kia', 'Main to khta hun k bna lo mood ab ', 'Kahan hy main uder hi hun', 'Yar main ready hu.mian se puch le?', 'G abi kha rae khana main', 'Sir my gher aa gia ho', 'Dost k ghar hu nashta karne lagay hain', 'Main just fact bta rha hun', 'Wah phir a sakta ha abhe ya phir kal', 'Hum to gari par gaye thy', 'Hahah spcl duaien start krti main ab tery lie', 'Ok ap karO mil jaye ga nai tO ma dondh du ga but aj nai bcz subhO ppr ha', 'Ghar ma re set kasy ho ga ?', 'Ghar ho ya uni a gay? ', 'G ap bolain kiya baat h. ', 'G pata chala haiiii me ag pata kartaa hnnn', 'Mian g mamo skp chalay gaye ha ?', 'Yaar ghar jaa kar batata hoon.... AA kon kon raha hai??', 'Nahi mae kudhi hi ghar ae jaho ga', 'Yr main txt send krny lga hun', 'Yar is lye ke kal me ghar ja rha hu', 'Saray mou pe phail jaye giii', 'Gar dy jana dakh lo ga', 'Main chutti hi nahi karti :-D', 'Main pata krta hn dosaron sy.', 'Yr kehty hai 1 ganta lgy ga ho jaye ga thk', 'Yr min dost ka sath chale gao ga to pounch min aya.', 'Sir abid sahab keh rahe hn garam ande bhi hn', 'Han yar ab lga di hain to karni to pare g na', 'gyA h ni nashta krny...ab jaga hun ma', 'OK abhi mae perh raha hoon Raat ko Bta doon ga', 'Ghar me or koi nai ha is lye muje lazmi jana hu ga.', 'Me to abe kr rha hu', 'Gandi bachi w8 ni kr skti thi ', "Nahi...abhi ghar nahi gaya jaa kar pata chalay GA :'(", 'Main tw tyar hun janay ko amii abu ny mana kya k nae jana', 'Nahi kuch time main mil jye ga', 'Main to thak gya hun smjha smjha k', 'K abi to bs khari hai chacho soe hue hain', 'Pahle roi thi ab bas matam aur chup LG hai', 'Mein ne to ab eid pe jana hai', 'Sir apki keys apke pass hain na main ghar nikalne lag hn', 'Mein pohnch gaya hun, tm log abi tk kahan o?', 'Or ustarhan mai to halka hoojaon GA per phir yeh Jo bus mai hai na saray unhay kuch hoojana hai', 'Fazan main abi bahut dhor hon', 'Haan mje chuti hai aj ghr e ho is liye poocha', 'Xarr ab gar a gaye hain tu pta ni kahan tha ', 'Gi aj 7:30 kae bad ghar hi hoon ga', 'Ha yaar pata nahi ab ka khata ha', 'Umair mery ghar jai or daki ghar wale ghar hi ha kya.', 'G ma aiman bt kr rahe hu agr ap saira ha tu', 'Sir gher ho.\nAj SP ni aya Muneer Bhi sy bat hoi hy', 'nashta krny ai thy ab ja ry hain', 'Oye adeel ghar ki taraf ana yar main aik cheez bhul gya hn wapis ghar ja rha hn', 'Han bta dya ha,sb muje sakte main aa kr dekh rahe han', 'Ghr hu paper ki tyari kr rha hu.', 'Main guliana say nikal aya hon ', 'Yar agar ap a jao to hum abi change karwa lain', 'Ok subha bta dai ya abi aja bhair mai ata hun', 'Tu main soch raha hn ... Aap wapsi pe leti aayen', 'Ok baba main khud e maan jati hn but ak shart pe', 'Yr gari khri krne pary ge.', 'Oye mein idhr kharaaa hn chapli kabab waly ky pass', 'kher pind b ni kh skty akela apna e ghar h yhan bss ', 'or sunao kya hal h? or khana khaa liya?? ghr ma sub ksy hn...', 'Gr m se sb ksy hn', 'To chup kr k kha lo phr bata dnaa', 'Raat ma parho ga na abi to utha ho', 'Or aap sunaao kia ho rha hai' ...
#
# Nai mje nai mili mail..mene check ki ti
# ['Nai yar mje to pta e nai kuch', 'Mjhe tu ni lgta k mere se milti he ....  ', 'Nai mje kaha ki pari yy', 'mjhe koi msg nh mila tra', 'mje paaaaand ni ai koi kkas ni ti', 'Ni mn ny to ni dykha', 'Ni tu yar m ne ku kehna', 'Pta ni yr mujy b ni pta', 'Ni jo kaha us ny he kha mn ni kch bola', 'Janu aj a jao na milna :-D ', 'Ni ni mn to jna haaa', 'Yr ne mila dubra send kr', 'Ni aysi koi bat ni he', 'Me helmat ki wja se bxh gya ', 'Mje laga ap bizi ho jo reply nai kiyaa', 'Mjay reply ne kri wo :-|', 'Ni ni bta kr sou ga mai', 'Me lec ap ko mail kr diye hain..', 'Dalwa lo me a k pese dy dun ga tm ko', 'Samjh ni ai tere msg ki', 'To us se mila or to ne phr bhi ni pocha', 'Ese na kr mne kbi rola dala? Na krta tu msg\npehli br kam mila itne dinu se bth ra us m b tu rone lag gia he yr', 'Ni me te b0lya v ni c', 'Han mje b bht afsos hra hay..tmne aj pehnna tha na', 'wsay unho ny b ksm kha li muj s na milny ki', 'han ammmi se ki ti bt meeee neee q pocha tm ne', 'Nai main bi waila hun aj kal', 'Kre ja na msg tu me choty mbl se hu', 'Ni mje in sb me koi interest ni', 'Ok me leti aon gi..mama ko pele e keh dia tha mene', 'Me ne ak din snai ti achi bali usy .', 'Ja k ly aie ksi be shop sa..', 'Ni main kbi ni mila, jxt frndz thi, g.f k0i ni', 'ni koi msla ni hai unho ny khud kaha', 'sir ma ne mail kar di ha plz chek tht out', 'Mje shadeed neend ai ha mahi', 'Tmy kia h me jo b krun', 'Han yr mil gae aesay he krna hai', 'Helo?kesi ho yr?k0i rabta e ni?', 'gyA h ni nashta krny...ab jaga hun ma', 'Nai tm na lo ten..sai ha', 'O v check nai kiti 2 din se', 'Ub mila tmara ye he msg bs', 'Mil ge tw bhej do ge', 'Es msg ki smjh ni ai', 'Telha ko mna lae....or papa ko bi......', 'Ni mene ni jana dost ny jana ay', 'or kxa mjhe ata e ni tha', 'Email kro jinna v bnya a,main tuanu apna send krn lgan.', 'Hey tmne call to nai ki?', 'Yehi mdl twn ma he khai b mil jaye acha sa', 'O nahi yar mujy tu nahi mila wo', 'tm ai ni to usy e dy dia tha', 'tusi online e na hoya kero....', 'Pta ni ku ni kr rha', 'Nai to0o0o mjy to ubi tk k0i parcel ni mila', 'Irsa rply b kr de behn! Kal ana e tm ne???', 'Nai fee waghera kisi ki b nai dety', 'Ni tere begair kahin ja skta hu kia', 'Hn me ne le lye hn', 'Sir ne pprs nai check kiye..me abi udr e thi', 'Ni yr me keh ra hu k tu us se keh', 'nh gari py. jana h mama jani mane or nadia bji ny', 'Idhr koi ni he isi lye tje kha tha...', 'Us ki trf sham ko jana he me ne', 'Nae ghr ja k kru ge', 'To ma ne ye kab kaha mje na sunaooo', 'Yr un me se rzlt crd to ni mlne abe..', 'Hn to or kia itny msg kiye m tmhy', 'Mili v t.. Asal mein nhi t, blke chaal t ek', 'Mene msg kia tha reply nai aya', 'Is ka mje cnfrm ni pta.', 'Ni mje uski call ni i.\nYehi tou btaya tha apko. ', 'Usko msg kr den.. Yr mje to tempratur ho gia ha ma to kal ni ja sakta', 'Is nmbr ka pata ha. Jo tmhy send kia.', "Han yr pele e kra do to acha hay..mene wese trousers or ban'ne klye dene hn", 'Ni ami ki mami ayie hain', 'Jani ap ne last txt me 2 mnth kha ha me ne is lye kha ha', 'Mjy pta ha abu ne ijazt dy e dni ha....\nTm mehanti ho acha kam kr skui ho.,', 'Yr tu phr mje kre ja msg me fwd kri jata ho', 'Wo khe rhi ha ye muje mili hi nai me ne tume kha bi tha ke milna usy.', 'Nike wali keh raha tha mjhe me NY ni li wo,', 'Han to vo to sub sy best he mai ny to is liyai nai bola ke tmhe khe khe ke koe faida nai magwani to he nai is ny to phr ye boil kry..', 'han tmari cl aai ti mjy', 'Me ni Jana aj us ke rm me ', 'hn or kya.\nna tjhe smjh arhx na mjhe.', 'Mene puch h sub se koi b ni ara ', 'Yr ma dost se 200 lya ha ghr se nae mla plzzz kr dena', 'Tm ny bna li k nahi', 'yarrr agly mnth b abi grmi h ho gi...sardi to ni', 'aa ja mil ly...kal wapis b chaly jana ma n', 'yar kia bagairti ha mene to wapis jana tha abi kl :-P mtlb chtii', 'Us time sofia b thi pas islye mene zada bat nai ki', 'Han .. Pochta hn agr aj na mila to jama nhi karwaon ag ', 'Sala ma to tiar tha...  Mana kb chuss mari ha...,', 'Mujy kia pta me to pini h bs', 'Na g na etne jaldi maina koe nae ana.', 'Mje b ...
#
# Yr us din mai pura din bzy rahe vo mujy awne hi nai dy rahe the or kal b aisa hi raha koe naw koe aw raha tha aj to mn soba sy dekh rahe hn k tm aw jaao lkn tm to dada jee ke taraf..
# ['Yr masla pta kia ha. Yad ha tm log us din upar aie tha to papa bol raha tha gusa kr raha tha. To mja yaken kr us din papa pe bht gusa aya ka humari jaha bni hue ha waha to kam se kam rehna dae. Aksar esa hta ha mra ya arslan ka koe dost milnae a jae to papa dant ke bhej deta ha.', 'Tmhe to bnda mzk mn b nai khe skta ku ke tm to sch mn hi khana pina shuru kr daite ho..', 'Mein is puri story mein ek cheez pe bht heran hui t k haya ne jo oot pataang form fill kiya th sabanji uni k liye, usay prh k jahan jese shakky aadmi ne shak k bjaye muskuranay pe iktafa kiya!! Herat h =-O :D wrna mje to pakka yaqeen th wo ab is k liye b haya ko check krega k kahin wo waqai drink or smoke to nhi krti, huhhh.. Koi baeed b nhi t wese :/ =P', 'wo chahy apny gr gxa tha tjhe khud daikhna chahye tha.\nor uper sy bl rha tha k papa ny daikha bs thk h. kya mtlb?\ntu abi b cheat krny k chkrn ma h?', 'yar wo may be aik do din mein uet to milne ka soch rha tha ,', 'Haha hmri to tymng chnge hti rrhti r kbi pura pura dn ni jti ... pr ab grmi hny lgi hy to lyt b jjna shru ho gy hai ... phly mausam thk tha to ni ja ri thi ... ulti khopri fit hy un me to ... ', 'Yr us k bahi bhr chala gaya na', 'O ja yar tujy btya tu tha k tm a jana pr tun pata nahibkahan gya tha', 'Daikha tha  main NY nai mil raha  tha  udar  sy b yara,,,', 'Tu na b bdlta tO kOi bat nai the apni trf sy tO tuny jwb dy hi dia na..ab chahy bdl k dy ya wsy dy..', 'Jb ma chota tha to mai röna lag parta tha or sami bai b. Aj b hum se apna bkre ki ni daki jati.', 'Ya hum tumare ghr ajaein gy phr wahan se chlein gy..', 'Yr time e nai milta kch krny ka sara din uni mai guzar jata hai....', 'Oye agr nahi ho rha to bata dy wo roz poch k sar khata ae:-P ', 'Wao me sara din tenshn me rha aur tm ko mza aya', 'Yr ali sy mila tha to tera pocha tha mainy hahaha dono jutt ikhate ho gy.', 'Rana sab haaj py ja rhy ho bro milty ak do din mai ... ', 'aj subha parhy thn nashta kiya thn phr thora parhy thn bahar nikaly thori dair thn khana khaya or ab b parh ra tha', 'Han, mene b ye socha th k ek dfa khudi keh deti sbko.. Zahir h wo pehle jo b t lkn ab uska kirdaar sbke saamnay th. Lkn phir mene socha k uski family mein buray log zada th jinhen moqay ki talaash rehti t, shyd isi liye wo zyada drti t.. Wrna itna b drni ki baat nhi t us gadhay se :@ ek pathar uttha k uske sr me b de maarti, sb set ho jana th..', 'Yr mujy teri samj nai aati kya chahta hy... reny dy idar e reh', 'Yr us na pehy par jana mery tm na mjy moti ku kha kra dy lari hamri ab.', 'Ik din ke bat hoti to theek tha ab to roz ka masla bn gea ha.', 'Zarorat nae thi awaz sunane ki...mairi awaz kn si bht achi hai...fazol hai...tm sunti to kan bnd kr leti', 'Nai mai nai kheti tmhe jo kaha he bs vo kro jaao ab..', 'Dekh kai ru aik din nai aya or kia kia ho gia', 'Wo khe rhi ha ye muje mili hi nai me ne tume kha bi tha ke milna usy.', 'Lkn mujy to khana b bnana awta he vo b achee wala..', 'Mujy us sy bht pyar tha ... Or hy b but ma us k khny py chup hun ... Ma chahta hun k wo khush rhy jaha b rhy ', 'yarrr ni yarr haris ma n ruk skta papa ny bht sakhti say kaha ha k sham tk nkal jana ha', 'Mjhy rooz dant parti. Tv dkhte dkhte soo jata. Subah baba aa ky off krte :p ', 'Han yar tm khud dy jana wo tu nahi aya ', 'acha rha tha bs yad e krty hn ab wo din', 'Mujhy bi awaz nai aa rhi thi', 'Me ghar itna rha hi nai. Dada abu ko le kar gya tha. ', 'Papa or telha sun ko srgdha ae rahy hy......', 'O yar tm nay kn sa jok aj sunaia tha. ', 'Mjhy dair ho jaey ge atay atay ...mai abhi bus mai betha ho....', 'O yr khana kha raha tha.', 'Nhi abi nhi ki acha kiya tu ney yad krwa diya ', 'Han bta dya ha,sb muje sakte main aa kr dekh rahe han', 'Yar dykhty abi humari kuch khas tyari b nai hy. ', 'Dfa hu kha na nai a sakta me phr avie bakwas kri ja rha ha.', 'Yr jtni jldi ml jaye utna acha he...', 'Han mj se zaheer aur umer b poch rhy thy kia hwa ha.\nTo me ne b bta dya jani :) ', 'Yar yatem khny b tO jana ha tjy btaya tO tha', 'Yr tm ko kia btaun jb kal  ao gi phr btaun ga ' ...
#
# Lakin wo abhe dar dar ka chalata ha
# ['Pata nahe ab kahan chala gea hai kamina', 'Han khty ab nikal ry to aba g ko kangaal krr k e wapis ain na', 'Woh dars k liye use hota hai ab', 'Han yar ab lga di hain to karni to pare g na', 'Many abi dahe ka payala khaya hy.', 'Han yr ye masla rahay ga ab ', 'Dkh lena awain phas na jaon', 'G abi kia aur ab lhr jane lga hn', 'Tera dola sola dekh kr dar Lagta ha', 'Han keh diya hy wo bta dy ga apko', 'Lagta ha koi sasta nasha karnay lag gya ha', 'Yaar kasa ha to sab thek ha', 'Kahen b yr dor chlty hn', 'Mara mbl bund tha abi khola ha', 'Han kiya hoa koi masla ha kiya', 'Thek ha lekin tu to cha gya yaat', 'Ruk ja abhi cng dalwa rahy hain', 'Hen abi aj ka kam ho jay ga ', 'Han kr lo waisy kuch khass to krwaya nai hy. ', 'Han esi bahany larkiyan b dekhnay ko mil jaye gi', 'Na kar yar rulay ga kya', 'Ne khala m chlta hn wo tamatar la k jany hn', 'Hamay sobia zaheer prha rahi ha', 'Han wo wapis a rha hai', 'Sir likha tha kahin mil nae raha ab usi se puch lain', 'Theak ha janab ya lhr main kb tak rahain ga kio ka main jumay ko fre hn ga', 'Main tw tyar hun janay ko amii abu ny mana kya k nae jana', 'Yaar kal bethnga aj thaka howa hn', 'acha. ktni dar ka kam ha.', 'Wah phir a sakta ha abhe ya phir kal', 'chal sahi hy ab mehnat kr ', 'Qabristan waly k num dy dy ma khud mill leta hoon kal us sy', 'To krne dy un ko yr abi se sekh lein sb kxh', 'Han bas nikalne lge hyn tk kahan ha ? ', 'Or khala ne kb nikalna hay?', 'Hassan ko bhi bula lay agar ata hay woh tu', 'Ha yaar pata nahi ab ka khata ha', 'Min wapis ha gaiya ho ab to.', 'Han yar chalta ha to thk ha', 'Sochna kia ha jani. Paki bat ha', 'Is ka matlab wo uder hi hy ', 'wahan b chly jaty hn. gr ka th0ra samaan lana h', 'Han chaly jain gy jnab ma ejaz sy contact kr lon ga ', 'Gr hn abi me to kb ka aya hwan hn gr drd ki wja se', 'Ha bol bi kya karwaya ha phr.', 'UnhO ny kaha tha k wo khud aye ab tu dekh ly', 'Usi k leye teyariyan ho ri hn', 'Wesy b sab usi zaat k hath mein hain', 'K abi to bs khari hai chacho soe hue hain', 'Yar ma cal tak kar day ku k mujay us ki zarorat thi', 'Hamari nazar sae apna ap ku daku gy to pta chal jae ga ku marte ha ap pae.', 'ea ke 2 dafa piaton change krwa chuka hu masla whi ka whi hy', 'ahan...wo ewe chakr lgany gy thy..or malik ko sham ka kaha ha ', 'Kafi behas kr k baith baith k aa gaxe', 'Rehan say baat hu rahi hay ajkal', 'Je janab gc main bohet ash ke ha', 'Han kal baat kr k btana mjhay .', 'G janb woi ker raha hn', 'Han jhot to bht bolta ha ab kya hoa btao', 'Ha yr kal ko tery jese to na hn k kis b sikhani pari', 'Koi pata naiii wo larkay ne laptop nai lena abiii ', 'Oye eesult ka kia bna pass ho gia naaa', 'Wapis kab janay ka plan hay tera', 'V r coming now aftari k bad wapis chale jae ge', 'O nahi yr abi tk koi flat nahi mila hy wahan ', 'Han wahan se ak larky ne pta kia tha.', 'Wese kis k sath jane ka irada ha :-P', 'Hum ghar sy chal pary hn', 'Hawn g khilaa tw main dun gi par apko khana paray gaa lazmii', 'Par yar Kia kha sakta ha', 'Gar dy jana dakh lo ga', 'Zohaib kh rha ha uss ka ghr bacha prhna ata hain ksi aur din chala ga,', 'Jana dy yr. Mausam ku zror fark para ha likn abi dhand kha ai ha?', 'Han ese e ha khud chori ha', 'Han yar kal jana hy zaroor', 'Half hur tk lhr pohnch jaon ga ', 'Ok chlein theek ha ma komal sy b pochti hon', 'Mil k chalty ha agr thora wait kar sakta ha', 'O nahi yar mujy tu nahi mila wo', 'Ni mera dil chota ha khoön dak kr mja chakar ata ha.', 'Yar agar ap a jao to hum abi change karwa lain', 'Han yun guzar jane pta he nae chalna', 'Han cls ly rha tha ab free hon', 'Parhne ki koshishb kr raha hon.', 'Yar us na muja is Bara ma kuch b nahi bataya', 'Dost sy pocha ha wo khta ha 2 log khelty hn', 'Me to abe kr rha hu', 'Mera b kam thek chal ra h', 'Han kfi bhtr ha ab..chunian aa gye ha....', 'Nahi Yara abbu keh rhy hain k rehny do,,,', 'Dekh ly phr bgrtian kr rha ha', 'Phr aur masla ha ma dekhon ga raat ko', 'Pata nai kab krti hn tabiyat bht kharab hai', 'Dada abu ko ambasy le kar jana ha. ', 'Ufon ki franchz tmary gha ...
#
# W.a.salam who's there. Actually mbyl reset hogya h to contacts abi saray save nhi kiye..
# ["Who's there? Actually, mbyl reset hogya th to abi sb contacts resave nhi kiye hn.,", 'Wsalam, to phir kiya kaha ha sir nay?', 'Yar me ne fone new lia hai mamu c contacts dlt o gya the', 'plz apna name btao mere saray contcts dlt o gye hai', 'Soban wasif abdullah rohail sufyan ko bhi phone kar k bolo lazmi ayennn ', 'Or han sary msg ak e number sy send krny hain. ', 'Han chaly jain gy jnab ma ejaz sy contact kr lon ga ', 'Raheel say contact karo is mamlay mai', 'Wo is waqat office ma nahi han.', 'Shafaqat ki abi abi call i t. Salam derha tha tme. Qabool kr lo...', 'Salam bhai g kiya haal ha', 'Phone per baat kr lo. Wo kahi nikl na jai', 'W salam jee wo saad k pas hae mene usko kaha hae k bhje.', 'Wese b muje tu apny msg count pora krna hay :-) ', 'yar kisi ky sth contact hi nhi kia pata krun ', 'yrrr ali poch raha hy voh baht preshaaan hy k yeh kahaaan chlaa giaa hy.. Us sy contect kr ly ', 'Han g bro g kia hal chal hy kal mera phone off ho gya tha ...  ', 'Hel0?misbah mra numbr of ha idr msg krna,', 'Phr waha sy tayota pr lahore', 'Waalaikum salam... sir mai to thk hn ap dunain', 'Sent item waly msgs ... Ya pata hy kis nmber py send krny hain ??  ', 'Yar mujhay wo app nai mil rahi jo sirf sent sms ka backup banaye ', 'Wsalam, ma theek hon bus sir ma derd ho rhi ha or neend b nai as rhi.. Guest ay huwy hain ghr.. Tum sunao kia haal ha?', 'Multan mn koi ni.... Lhr wale send krde whtsapp pr', 'Mian ka phone aya hai. Keh raha hai plan cancel kr lo aaj ka bhai khurram aye hoay hain. Us say baat kr lay khud hi. ', 'Tmhara bhai uthaye phone mera kya qasoor', 'Hussain ka bhae MASHALLAH ho gaya ha aj.mobile ki battery bilkul end ha r signal problem bhi ha. is lye call nahi ki. will talk to u later I N SHALLAH', 'Nei msg kiya hay bt abhi tak reply nei aaya', 'Name confrm kr ly phly k saif ullah khan ka e account ho ... Mujy msg recive ho jay ga jb wo submit krway ga. ', 'Yar ujala sy puchna .... K mujy uska phone chahiye 2,3 din k liye ... Kashmirr ly k jana hy ...  ', 'Salam sir.\nI refred to u by sajwal baryar from astralia. He talked to u so plz pick up the phone for further dsicsn', 'Oye Aa v jaa yara Ghur sy phone arhyy hain.!!', 'Sameet talha ne kul ana hy wapis..', 'Wo uni me hi ha yawr usko call kr ', 'Salam apny namaz ada krni hy?', 'Thorai din pehlai tak nasir ka phone aya hn ga tujhai hana', 'Mera ye num tha mere pass ye save kar lo dosra mobile kal dost k pass reh gya tha', 'Irsa mera verification code agyaaaa.. Tum b isi wqt check kro. Jldiiii', 'O bhae mery mble p txt y phn krky bta to n aj ana h k ne...ana h to phnch ja r mjy bta phn p ali haider', 'Ramzan me ai this call us ki LST time mar GI phir WO shayad,', 'W.a. Bht bht mbrk ho. Wslm ', 'Inshallah sb thek ho ga...abhi result check nae kr skta?', 'Par jab aye ge to zaroo ap ka Salam du ga', 'Neelam vally dne karo kabhi nai gae sab ko kya msg abhi dne karo baad mao masla hta', 'Wo waly msg send krny hain ... Jo khud type kiye tum ny .. Okay. ', 'wahan b chly jaty hn. gr ka th0ra samaan lana h', 'Mera msg mila tha ramzan mubarik wala?????', 'Sir apnay apna pasword change kr lia?', 'W a\nAp kb milny aa sakty hm? Wslm', 'Rabia ko inbox ma kh da ka hamara group ma ajay. ', 'Oye logo.. mera telenor ka num delete krdo. bs ye warid walay 2 save rkho. telenor ka ab baba k pass hota h or tum log usi pe birthday plan discuss kr rhe ho -_- :P :v :D', 'Was.shukar ha ALLAH ka v al r fyn.aj kal ami ki taraf aae hui hun.ap sunain hwz every1 there?Aj kal hasan ka sar bnanay ki koshishain jari hain.eshal kaic ha?', 'Nahi Yara abbu keh rhy hain k rehny do,,,', 'Oy kithay wain emergency call attend kr', 'Haleem sb ka msg aya hai. Apka puch rhay hain', 'Mannan sahb reply hi nai krtai', 'Wapsi aajana islambad paisy ... Eaisy paisy sy aa jain gy kia khyal hy ??  ', 'yahi tr smr m ds parh ri bs clear hojye ', 'Hamay sobia zaheer prha rahi ha', 'Qasam say .kaha tha.yr is ne', 'Sobi aa gae acadmi se tu miss call krain', 'Yar wo app tu saray sms ka backup banati ha. Sent sms ka tarika bata de ...
#
# Yea i know that i guess everyone is concernd abt their marks enjoylimits main hi karna chaiye
# ['Mje to yae btaya ha sir ne result..shyd us k end pe xda marks krdiye hon', 'Ghr waly khush hn marks se?', 'Wesy ye scaling downwards ki bjaye upwards b tou ki ja sakti thi k mam course k marks barha detin:P ', 'Mujhe fikar hy graph ki asi k marks ki', 'Hawn yar maza tw ay ga par kam n mehnat bht krni pary gii competition u knw naa', 'Students tng hain us sy mje b aksar kehty hn ma to students ko bra relax rakhta hun', 'OK mai students ko bta deta hn', 'Tmhara kitne marks ka paper hai', 'Me mausm enjoykr rha hn', 'Sir g aap ne meri atendence mark kr di thi ', 'Tm ne kaha k just 5 marks,.to maine kaha k 1 mark ki bhi bht value hai', 'Yr tahir k ktny marks bnay hain?', 'Masooma buckle up sessionals ara hain :-P apka bnda koi nai leta but apka marks teachers na la lna :-P', 'Nahi its ok assignment abhi mila hai nahi tension subko phly say hi hogye groups ki ', 'uasam k kis subject ma sb say km marks ay', 'Yara tu b Alhamdulillah achyy marks lay gya hai.!!', 'Sir ap ne meri attendnc mark krni ha yad se ', "Ni numbro wala msg ni maths wala r ek us se pehla kya tha 'wahi thek rhe ga hmare kam k mtabr'..ye dono ksi r ko krne the wo glti se tje ho gye.", 'aur kisi ke marks pata chale!??', 'May net pe apne dost ka ghr ja ka check krta hn aj.thnkx. ', 'Yar,matric ka tym acha tha...pta hi nae tha kuch,so raha tha n ghr walo ne othaya n kaha k result aa gya,...ab to tensn hi bht hai...', 'Main just fact bta rha hun', 'Main tu ghar hi rehta main kahan ja skta', 'Mera Bhi Aik Subject Rehta Hai Mera 3.07 CGPA Ja Rha Hai.', 'Nai marks awaghera ka ata hai bs ', 'Ya tum milooo aa k important bat krni hy ak okay .... ', 'Esa kr math ki book pakro aur idhar pohanch jao yahan a kar classes lo apni . Aur math ka kam bhi kr lena krna ', 'Dont worry yaar\nAap ka to waise b ye additional attempt he\nAnd IA improve b ho jaye ga', 'Wesy cs m uni itni mater ne krti hmry sir btaty hn k wo apki skils dkhty hn k apko ktna kam ata hai isly ap jnsi b uni jow ziada focus apni skils p rkhna ', 'ufff itnaaaaa sara gusa bhai :-P yr bs exams ma bzy hn kl sham ko aon ga', 'Theak he ja rahi hain asignment or quiz per zor ha', 'Haw yeh kya baat hoi main frnd hon isliye chati hon k khud mehnat karo :-D', 'Mind nai kia meny..aur agr ap kO lgta ha k kia ha tO ma kya keh sakta hO...', 'Ha yaar us ka b acha result Aya the', 'Yar main calculus k notes bna raha hun', 'Insaan.ko itna careless b nai hona chahye', 'Hahah chup kar jao lagta hai class leni parey gi tues ko :-P', 'Yr net kharb hua hai wo thek krwa rhy hain.', 'Hmm.. Kehna b chahye... Authority matters alot :-)', 'Yehe tw msla hai k stdy bhe paar0o hai', 'Yar mai university hun ghr ja kar daikho ga', 'Mein b theek hn yar :)', 'Han bta dya ha,sb muje sakte main aa kr dekh rahe han', 'Meri tenshn na le to apna s0ch', 'Mein ghousia chk pe khara hon', 'Nikal gaien howay hai waisay hi kah raha hoon kyun Kay cantt say aaon GA to thora time lag haie', 'Hahahha keh deta hoon sbko fikr na kr', 'Haha :P cgpa b enter nhi kr skte.. Bs %age e enter ki.,', 'Main tu gari main beth gya hun but wo pagal ka bacha chala hi nahi raha', 'Is k total 5 marks main jtni zyada bat utnay hi zyada no hain jnb', 'Mein university mein baad mein baat ho gi', 'Suny m aik bt s0ch rha hn', 'Mein daikh hi nahi raha. Im studying. Lolz', 'Yar wo paper k uper he karna tha mid wala b ur final wala b', 'Yr de ja mein ne b bnane hai assignment', 'Sir agr ap subah jldi ge tu plz meri b attendnc mark kr Di jiay ga', 'Phr tere tk he thk krta ha.', 'G wo thek ha per btana kya kya ha like k first assignment  similarity scores mn kya kya ae ga report mn ', 'Tk hai ab aaye na aaye\nMain ja raha hn', 'Yar me ne ja ke quiz or assignment tyar karni ha.', 'Nai tm tensi0n na lo mene n0te kia tha lectr me tmy likhwa dn g,', 'Shukar hai 60% aa he gae wrna waj jani thy', 'Ni bhai yeah to mazaq ho raha hy', 'ni bhai mein waha hi thk hn tu waha a ga mein usama danyal jate hain,', 'Nai main to gar main bhor ho jatta hn ', 'hahah chalo shuru m smj skti hn', 'Tum ny jo lik ...
#
# Oyee Aaadu ko chor b jaa
# ['Oye bhai jo bhe bnaya ha bhej da', 'Oyee shokhi.. Me aa gai hon :-) ', 'Oye tou lahore aya tha kaal', 'Nai yaar tu pagal ha kiya', 'Wo aap Ko dekh k aur b latto ho jaiengy ', 'Yr us k bahi bhr chala gaya na', 'Oh acha gud ha gunah dhol jayain ga', 'Oye devdas teri paro kidr hai', 'Eik jaisa bahana ho jae ga', 'Ha yaar us ka b acha result Aya the', 'Yrr aj mai jaldi aa jao ga', 'Nahi yaar papa na to May ma Aya ga', 'Q ja koi nahi skta yar', 'Yad nai ha ap ko bhi', 'Sir my gher aa gia ho', 'Yaar daewoo kaunsi jati hai kalma chowk', 'Oyy woh speaker chahye mjy aj', 'Haan papa ne bola a jao mere sath e ', 'oye chup kr ja......marrr na jai mairy hatho', 'Wo ichra h subho a jaye ga', 'Oye eesult ka kia bna pass ho gia naaa', 'Raat ma parho ga na abi to utha ho', 'Nahi mae kudhi hi ghar ae jaho ga', 'Yaar pohnchty pohnchtay time lag gya', 'hm ajkal tooi door ee aisa haaaaa', 'Oye adeel ghar ki taraf ana yar main aik cheez bhul gya hn wapis ghar ja rha hn', 'Me aa jaooon ge time per', 'Yaar mai eid abbotabad mai e kron ga.', 'Oye agr nahi ho rha to bata dy wo roz poch k sar khata ae:-P ', 'Yaar kal bethnga aj thaka howa hn', 'Yaar ghar jaa kar batata hoon.... AA kon kon raha hai??', 'Me aa rai hon rasty me hon', 'attend ee nai kr ra woo', 'Haahaha lb chora plane hu ga', 'Muth baad me maar lai bhr aa lun', 'Hahaha koi nai ho jaye ga', 'Oye telha kyun nai aya juma parny', 'Oye mein idhr kharaaa hn chapli kabab waly ky pass', 'Yaar tu kiya karta rehta ha ', 'Yehi mdl twn ma he khai b mil jaye acha sa', 'hhahahahah jado koi gal na aye fer chawal e lagdi ey....', 'O ja oye koi teacher chutti deta hy?', 'Yrr tu mama ko stop tak chorr din', 'Oye shadi karwa le tm na', 'Hahahah... wakay e asar hnda ae mnu aj pata chal gyaa', 'Oye Aa v jaa yara Ghur sy phone arhyy hain.!!', 'Oye Hafiz aaj acdmy gya hai ??', 'Nahe adhi rat sota ha r adhe rat jagta ha', 'Yaar ab dekh lay filmen cjla raha hay', 'Oye, madam aa gai class mein?', 'Yr tera subha sai pooch rahai hai...', 'Yr shor bht aa rha he', 'Oy yar cr ka nmbr snd kar', 'To nae kya karne hn. Chor yr.', 'O ja main koi nahi jana', 'Yr min dost ka sath chale gao ga to pounch min aya.', 'Ha yr wo b la Aya ho Vera', 'Me sch rha hu bhr chla jao', 'Me to abe kr rha hu', 'Ohoh acha to ye bat ha.', 'Yr ma na b trailer dekha ha achi lag rahi ha', 'Qadam brhao ik mnzil kreeb ha', 'Oyee light aa rai hai yar hamari 6 ghantai sai gai hoi hai', 'Yaar me ajau na lab me? ', 'Yar is lye ke kal me ghar ja rha hu', 'Yaad sy le kr ayie  mjhy chahiye', 'Han yun guzar jane pta he nae chalna', 'oYee tujy kia hua hai Asad Malik :P', 'Oee ruk ja 15 min mn ayaa', 'Yaar ma to business ma jana chata ho', 'to ye shaina A rab kon hai', 'Haan mje chuti hai aj ghr e ho is liye poocha', 'Han 1 bar aa gya to ho jae ga', 'Ohno keh char chohadi jana ay.', 'Yr ajow m w8 kr ra hn', 'Sai bta kab aa raha hai', 'Ha dani b ajaye ga usy ma bula lu ga', 'Me aa rha hu rste me hu', 'Yaar plzzz jaakay baat karlay us say...... Nahi to baad mai bachtaye ga', 'Hahahah ab tu dost k liyee itna b nahi kr saktaa jaa yaarrr', 'Han yr ye masla rahay ga ab ', 'Hahaha k0i jagh ni hai yr', 'Hn phr dusra vera le aya', 'Oye aja tu b kya yd kary ga.. :p\nKya khaye ga wsy..?', 'Oy abhi aa 1 mint\nTb ma ny wapis chly jana hai', 'Yar walu phn karu net na a ro!', 'Yar yai do numberia laga rahai hai', 'Oue mein ja rha hn ghr', 'Yr time dekh le ge na', 'Nai yaar note laga ha nazar araha ha', 'Ni yar sham ko hi chlte he', 'Oya saif sa milny chlty h ', 'Yar us na muja is Bara ma kuch b nahi bataya', 'Han yr mil gae aesay he krna hai', 'Han theek hy la kr aaon ge ', 'Hahaha sochi peya tr banda gyaa', 'O ja yar eysa kesy ho skta hy', 'Good yar n InshaALLH achi jagan o gi job dun wrry', 'tu suna kaisy kaisy bhai ko yad kiya', 'Oy 1o ko lab ka b ppr h ']
#
# Yar nend buht a rhi ha aj kal
# ['Nae aj tou nae kal ana ha', 'Nai main bi waila hun aj kal', 'Yaar kal bethnga aj thaka howa hn', 'Yar tjhy bataya tha ke kal jana hai ', 'Yar is lye ke kal me ghar ja rha hu', 'Nae to yr asi bt nae ha', 'Yr mai kal uni ajao ga', 'Han bhej dy kal leny jaon ga .', 'Mjhe aj jana per gya kaheen zruri.tm log kal ana mein aunga kal', 'Q ja koi nahi skta yar', 'Tu dara rha h yrrr Muhammad Bilal Ajmal', 'Han na yr such kah ri hn m', 'Oh acha to khal to aye gae na.', 'Mera quiz ha to ma ni arha kal', 'Yr farig kra kch nae h0ta', 'Han yr tm jeldi c thk ho jao', 'Ha to yha kn se andy dy rhan hn me', 'Nai yar mje to pta e nai kuch', 'Yr abhI uni se wapis a rha ho', 'Yar yai do numberia laga rahai hai', 'Han yr mil gae aesay he krna hai', 'Han yr ye masla rahay ga ab ', 'Nae ghr ja k kru ge', 'Yar wath to mje khud intne nahi ate', 'O ja yar tujy btya tu tha k tm a jana pr tun pata nahibkahan gya tha', 'Yar aj gr ma tendy pky hen, ma ni khany aja bhr chalain....', 'Han cls ly rha tha ab free hon', 'Yar yatem khny b tO jana ha tjy btaya tO tha', 'Han ab to tu esa hi boly ga na', 'Wah phir a sakta ha abhe ya phir kal', 'Me lhr hon kul swl jarai', 'Wasy maery to kial mae aram sae nikal jahy gi', 'Ur suna kasi ja rahi hay life', 'Pta ni yr mujy b ni pta', 'To krne dy un ko yr abi se sekh lein sb kxh', 'O ja yar eysa kesy ho skta hy', 'Nhe \nYar aj zra tabyat kuch theak nhe han..', 'Yar tu ne cng valy kam ka kuch kia', 'Han mama se kahna bna ky rkhyn m b a ky khaun ge', 'Han yar kal jana hy zaroor', 'Yhan  wse b koi nhe hta', 'O yar mujy khud nahi maloom', 'Han jana to ha jtna b ha chalo thk ha', 'Or aj kal kia ho raha hai', 'Nhe yr brish bht ho rhe m nhe a rha', 'Ni tu yar m ne ku kehna', 'Han yr dykha ha phly he', 'Yar ma cal tak kar day ku k mujay us ki zarorat thi', 'Ni ja rha yr bs wese e d0stun k pas ja rha hn  a jaun ga 2 din bd', 'Us ko bhir nhibjna tha yar hu', 'Na kar yr ayse na kar ab to', 'Yr ajow m w8 kr ra hn', 'Han aj arslan hmri traf he ha', 'Ni yr me keh ra hu k tu us se keh', 'Ha to thkawt utarun ga na axhi trah', 'Yr kasa hai.kya ho rha hai aj kal?', 'Rr kch yad ata tou btaunga zrur', 'nh yr aj dl e nh kr rha kch khany ko', 'Han g gr a gai he kal ka ', 'Han usky no boht achy thy intr ky', 'Ha prhai blkl thk ja ri ha.', 'Han yar ab lga di hain to karni to pare g na', 'Han wo wapis a rha hai', 'Nb a ja hm udr ja rae hain', 'Yr tu multan chala ja waha sy mil k a jai un k 7lhr', 'Ha g, ma road pr tha cal ka ni pta chala', 'Yr shor bht aa rha he', 'Yr ak brger la kr ai', 'Phr kia yhi k q chora mjy bhane dhond rae thy ye wo', 'hm ajkal tooi door ee aisa haaaaa', 'Han naaa.kr dy han wrna phr koi milna ni', 'Suna ha uni off hai kal', 'Yr us k bahi bhr chala gaya na', 'wo pahly b hmy cal kr rhien ti', 'Us se pucha tha kahta ha main theak hn main khud ata hn bt aya ni kal jao ga us ja pas', 'Qabristan waly k num dy dy ma khud mill leta hoon kal us sy', 'Ha yr kal ko tery jese to na hn k kis b sikhani pari', 'Ha sedha tw mai waqai nhe', 'Tm bi ja rhay ho kia ,yah aur kon ja rha ha pirr', 'Han yun guzar jane pta he nae chalna', 'Memona kb tk ana ha me nahny ja ri hun', 'Yr ye alaaw m0dl ha r l0king bi alaw ha', 'Han yar almst sub he gust ayn ga ', 'O yar tm nay kn sa jok aj sunaia tha. ', 'Mam bht aala prhati hn yr', 'Yr wo hut ka nechy he tha sub', 'Han ese e ha khud chori ha', 'Oye tou lahore aya tha kaal', 'Yr to aj daras p ae g ', 'Irsa rply b kr de behn! Kal ana e tm ne???', 'acha rha tha bs yad e krty hn ab wo din', 'G janb woi ker raha hn', 'Ja jaldi ja kr tatti kar k a', 'Pta ni ku ni kr rha', 'Han ha bs dua kro mil jye', 'Ur suna kia kar raha hay ajkal', 'Han xr mry mamu bi bs thek e hn ho e gye hn setl', 'Hello dost kaha hota hy aj kal.', 'Ohh wah kah bi diA ha unhun nay aur hm bi aik ??', 'Ham to kal wapis ay gy']
#
# Me ne kaha tha kehta ager phir me ne chak karwaya tu curve wapis la loon ga ur me jahn b kahn wahn tuja aa k chak krna para ga
# ['UnhO ny kaha tha k wo khud aye ab tu dekh ly', 'Han khty ab nikal ry to aba g ko kangaal krr k e wapis ain na', 'Gusa ks chez ka. Me ne kha k phr kia kehty ho.\nPhr ka yeh mean tha k me a jaon to ap ne kha he ni tha', 'Please tb keh jb mai na krwa k de raha ho,ho he nhe skte meri wja se khud krwa skta hai tw akar krwa le', 'Kya mtlb me ne baton mae lgaya hwa hai ap ko me ne to bs ap se kha k me kal soch rhi thi k kya khu puch nai rhi ', 'To chup kr k kha lo phr bata dnaa', 'mera b bht taugh hy par agr sath sath krty jao ho jata hy', 'Phr chawal se me nikalun ga tje . . . ', 'Mian se poch lay k wo kb tak fre hoga main to fre hu', 'Wo mere se mang raha ba . Me kahan se dun . Zeeshan ko pta chal gaya to bohat bura ho ga . Kisi se udhar bhi nae le sakta me kuch kro meharbani fahad ', 'Phan ka lora ejaxat le mujhe nae pta tu a rha hai', 'Yawr mujhe thora da bta kede krni ha ', 'Ni yr me keh ra hu k tu us se keh', 'Phupooo b yahan hyn meri kbi kbi wahan chali jati hon', 'O nahi yr abi tk koi flat nahi mila hy wahan ', 'Mjy to kuch aur he peena pary ga', 'Mein ghousia chk pe khara hon', 'Wo khe rha tha ke ma jao ga tu wo jae ga.', 'Haha hmri to tymng chnge hti rrhti r kbi pura pura dn ni jti ... pr ab grmi hny lgi hy to lyt b jjna shru ho gy hai ... phly mausam thk tha to ni ja ri thi ... ulti khopri fit hy un me to ... ', 'Sir likha tha kahin mil nae raha ab usi se puch lain', 'bahir a jaldi chalty hy me bhr khara hu', 'Nikal gaien howay hai waisay hi kah raha hoon kyun Kay cantt say aaon GA to thora time lag haie', 'Mera b kam thek chal ra h', 'Tu fikr na kr wo dost hi ha mera .wo dy dy ga jitny ma boloon ga .', 'Ya hum tumare ghr ajaein gy phr wahan se chlein gy..', 'Itni der jo mai keh rha voh krlo', 'G pata chala haiiii me ag pata kartaa hnnn', 'Ho jaega aik do din mein.meine ana tha aj but rastay bnd hein aur maslay hein.is week mein ana to hai sir se poochta hun kia suratehal hai', 'Hawn yar maza tw ay ga par kam n mehnat bht krni pary gii competition u knw naa', 'Mein is puri story mein ek cheez pe bht heran hui t k haya ne jo oot pataang form fill kiya th sabanji uni k liye, usay prh k jahan jese shakky aadmi ne shak k bjaye muskuranay pe iktafa kiya!! Herat h =-O :D wrna mje to pakka yaqeen th wo ab is k liye b haya ko check krega k kahin wo waqai drink or smoke to nhi krti, huhhh.. Koi baeed b nhi t wese :/ =P', 'Na kar yar rulay ga kya', 'Oye me to bhul e gae thi wo to me ne b dekhni e! Agr hmari cabel a rae hui to phr me larr larr k dekh e ln gi!,', 'Kahan hy main uder hi hun', 'Oye agr nahi ho rha to bata dy wo roz poch k sar khata ae:-P ', 'ab mere ghr waly na smjain bat ko tou me kia kru', 'Woh ap sunty ho to me ap ko ko ni na kuch keh skta.', 'Nahi kuch time main mil jye ga', 'chalo thk hai phir tum bhonkty ho jab mein kisi or k sath chala gao to,', 'Yahn se load ni milta yr kashif se kaho wo qais ko keh k krwa dy ga', 'Hahahahaha. Chal teak ha bun ja apna bkra tre se hy katwae ga.', 'Mujhay pata ha lekin tu use kar tu chuka ha na', 'Phr gand dikha rha he kabhi kam ni aya', 'O nahi yar mujy tu nahi mila wo', 'Talha kitney bjy kalma pohancho me or tu kitney bjy aega', 'Hawn g khilaa tw main dun gi par apko khana paray gaa lazmii', 'mera mood ku kharab ho ga', 'Mera khyal a nai kr rya', 'Han mj se zaheer aur umer b poch rhy thy kia hwa ha.\nTo me ne b bta dya jani :) ', 'Tu behes q karnaay lag gayaaaaa. Ye mera kaaam h :p aba to bolty e hain ', 'hahahaha ahuu parr din main :-P din guzar jata h mera wese har chz k bger .. .  hun rat ko to kch b ni h krnay ko sb kch thap hva para h wese e .. . ', 'Hn ,mager wo khud he us k no laga da ga ', 'Q k jani woh me ne idr office jana hota ha :) \nPason kia krain phr?\nUs bhej k kehty hn koi flat dakhy', 'Ha yar chaiye..agr la skta tw thek wrna kuch nhe h0ta', 'Half hur tk lhr pohnch jaon ga ', 'Wo khe rhi ha ye muje mili hi nai me ne tume kha bi tha ke milna usy.', 'Phr jb kahy ga jaha kahy ga chaly jaye gy.', 'Ok ma abi thori dair tk gar say nikal rha hn to muj say main road s ...

# %%
# Using top_n closest embeddings, create ChatGPT messages object (alternating user (text)/assistant(category) Q&As)
def create_messages(df_, closest_texts, top_n=100 ):
    df_temp = df_[ df_['text'].isin(closest_texts[:top_n]) ]
    messages = []
    for text, target in df_temp[['text', 'target']].values:
        messages += [
            { "role": "user", "content": f'Text: {text}', },
            { "role": "assistant", "content": f'Category: {key2label[target]}', }
        ]
    while num_tokens_from_messages(messages) > 4080:
        messages = messages[:-1]
    return messages

# %%
def classify_text_few_shot3(text_, messages_, model):
    '''Classify text_ using prompt_ and ChatGPT API'''
    messages_ = deepcopy(messages_)
    messages_ += [
        { "role": "user", "content": f'Text: {text_}', },
    ]
    while num_tokens_from_messages(messages_) > 4080:
        messages_ = messages_[:-2] + [messages_[-1]]
    if not verify_num_tokens(model, messages_): return None
    label_    = get_response(model, messages_)
    old_label = label_
    label_    = verify_label(label_)        # get just the category if response is too long
        
    # if label not found in response text - second, extended chat
    if label_ is None:
        messages_ += [
            { "role": "assistant", "content": old_label, },
            { "role": "user", "content": followup1, }
            ]        
        label_    = get_response(model, messages_)
        old_label = label_
        label_    = verify_label(label_)        # get just the category if response is too long
            
    return label_ if label_ is not None else old_label

# %%
# how one messages object looks
c = df_dev['closest_texts'].values[4]
create_messages(df_train, c, top_n=10)
# Out:
# [{'role': 'user',
#   'content': 'Text: Han yar ab lga di hain to karni to pare g na'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Pata nahe ab kahan chala gea hai kamina'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Han keh diya hy wo bta dy ga apko'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user',
#   'content': 'Text: Han khty ab nikal ry to aba g ko kangaal krr k e wapis ain na'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Tera dola sola dekh kr dar Lagta ha'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Dkh lena awain phas na jaon'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Woh dars k liye use hota hai ab'},
#  {'role': 'assistant', 'content': 'Category: neutral'},
#  {'role': 'user', 'content': 'Text: G abi kia aur ab lhr jane lga hn'},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Han yr ye masla rahay ga ab '},
#  {'role': 'assistant', 'content': 'Category: emotional'},
#  {'role': 'user', 'content': 'Text: Many abi dahe ka payala khaya hy.'},
#  {'role': 'assistant', 'content': 'Category: neutral'}]

# %%
# this simple iteration is faster than pandas df with tqdm
model = 'gpt-3.5-turbo'
start = time.time()
res   = dict()
count = 0
for t, closest in df_dev[['text', 'closest_texts']].values:
    if t in res:
        continue
    messages = create_messages(df_train, closest, top_n=10)
    try:
        res[ t ] = classify_text_few_shot3(t, messages, model)
    except openai.error.RateLimitError:
        print(f'\nText: {t}.\nRate limit error\n')
    except Exception as e:
        print(f'\nText: {t}\nError: {e}\n')
                
    count += 1    
    if count % 10 == 0:
        print(f'Processing text {count}. Time elapsed: {round((time.time()-start)/60, 4)} min')
        with open('data/res.pkl', 'wb') as f:
            pickle.dump(res, f, protocol=pickle.HIGHEST_PROTOCOL)
                        
        
elapsed = (time.time() - start)/60
print(f'\nTime elapsed {round(elapsed, 4)} min')
#file = 'data/res.pkl'
#with open(file, 'rb') as f:
#    res2 = pickle.load(handle)
# Out:
# Processing text 10. Time elapsed: 0.2187 min
# Processing text 20. Time elapsed: 0.5146 min
# Processing text 30. Time elapsed: 1.2399 min
# Processing text 40. Time elapsed: 1.4608 min
# Processing text 50. Time elapsed: 1.6706 min
# Processing text 60. Time elapsed: 1.9425 min
# Processing text 70. Time elapsed: 2.2348 min
# Processing text 80. Time elapsed: 2.8885 min
# Processing text 90. Time elapsed: 3.1024 min
# Processing text 100. Time elapsed: 3.3186 min
# Processing text 110. Time elapsed: 3.6155 min
# Processing text 120. Time elapsed: 3.8622 min
# Processing text 130. Time elapsed: 4.0695 min
# Processing text 140. Time elapsed: 4.3613 min
# Processing text 150. Time elapsed: 4.5798 min
# Processing text 160. Time elapsed: 4.8102 min
# Processing text 170. Time elapsed: 5.1345 min
# Processing text 180. Time elapsed: 5.4468 min
# Processing text 190. Time elapsed: 5.7625 min
# Processing text 200. Time elapsed: 6.0005 min
# Processing text 210. Time elapsed: 6.2346 min
# Processing text 220. Time elapsed: 6.5002 min
# Processing text 230. Time elapsed: 6.7309 min
# Processing text 240. Time elapsed: 6.9624 min
# Processing text 250. Time elapsed: 7.2057 min
# Processing text 260. Time elapsed: 7.5692 min
# Processing text 270. Time elapsed: 7.9091 min
# Processing text 280. Time elapsed: 8.1313 min
# Processing text 290. Time elapsed: 8.367 min
# Processing text 300. Time elapsed: 8.6205 min
# Processing text 310. Time elapsed: 8.8526 min
# Processing text 320. Time elapsed: 9.1127 min
# Processing text 330. Time elapsed: 9.3731 min
# Processing text 340. Time elapsed: 9.5967 min
# Processing text 350. Time elapsed: 9.8578 min
# Processing text 360. Time elapsed: 10.1606 min
# Processing text 370. Time elapsed: 10.4154 min
# Processing text 380. Time elapsed: 10.6395 min
# Processing text 390. Time elapsed: 10.8955 min
# Processing text 400. Time elapsed: 11.1839 min
# Processing text 410. Time elapsed: 11.4092 min
# Processing text 420. Time elapsed: 11.6413 min
# Processing text 430. Time elapsed: 11.866 min
# Processing text 440. Time elapsed: 12.626 min
# Processing text 450. Time elapsed: 12.841 min
# Processing text 460. Time elapsed: 13.1619 min
# Processing text 470. Time elapsed: 13.3855 min
# Processing text 480. Time elapsed: 14.1552 min
# Processing text 490. Time elapsed: 14.3822 min
# Processing text 500. Time elapsed: 14.7286 min
# Processing text 510. Time elapsed: 14.9727 min
# Processing text 520. Time elapsed: 15.194 min
# Processing text 530. Time elapsed: 15.4489 min
# Processing text 540. Time elapsed: 15.6905 min
# Processing text 550. Time elapsed: 15.9922 min
# Processing text 560. Time elapsed: 16.734 min
# Processing text 570. Time elapsed: 16.9981 min
# Processing text 580. Time elapsed: 17.2255 min
# Processing text 590. Time elapsed: 17.4508 min
# Processing text 600. Time elapsed: 17.7119 min
# Processing text 610. Time elapsed: 17.9449 min
# Processing text 620. Time elapsed: 18.1693 min
# Processing text 630. Time elapsed: 18.3809 min
# Processing text 640. Time elapsed: 18.625 min
# Processing text 650. Time elapsed: 18.8724 min
# Processing text 660. Time elapsed: 19.0931 min
# Processing text 670. Time elapsed: 19.3179 min
# Processing text 680. Time elapsed: 19.5509 min
# Processing text 690. Time elapsed: 19.7698 min
# Processing text 700. Time elapsed: 19.9988 min
# Processing text 710. Time elapsed: 20.7535 min
# Processing text 720. Time elapsed: 20.975 min
# Processing text 730. Time elapsed: 21.1982 min
# Processing text 740. Time elapsed: 21.517 min
# Processing text 750. Time elapsed: 21.7442 min
# Processing text 760. Time elapsed: 21.9933 min
# Processing text 770. Time elapsed: 22.2151 min
# Processing text 780. Time elapsed: 22.4488 min
# Processing text 790. Time elapsed: 22.7374 min
# Processing text 800. Time elapsed: 22.9628 min
# Processing text 810. Time elapsed: 23.1923 min
# Processing text 820. Time elapsed: 23.4286 min
# Processing text 830. Time elapsed: 23.9473 min
# Processing text 840. Time elapsed: 24.172 min
# Processing text 850. Time elapsed: 24.4004 min
# Processing text 860. Time elapsed: 24.6386 min
# Processing text 870. Time elapsed: 24.8738 min
# Processing text 880. Time elapsed: 25.0961 min
# Processing text 890. Time elapsed: 25.3219 min
# Processing text 900. Time elapsed: 25.5568 min
# Processing text 910. Time elapsed: 25.7736 min
# Processing text 920. Time elapsed: 26.0037 min
# Processing text 930. Time elapsed: 26.3318 min
# Processing text 940. Time elapsed: 26.7386 min
# Processing text 950. Time elapsed: 26.9623 min
# Processing text 960. Time elapsed: 27.2409 min
# Processing text 970. Time elapsed: 27.4598 min
# Processing text 980. Time elapsed: 27.7563 min
# Processing text 990. Time elapsed: 27.9807 min
# Processing text 1000. Time elapsed: 28.2107 min
# Processing text 1010. Time elapsed: 28.5639 min
# Processing text 1020. Time elapsed: 28.8254 min
# Processing text 1030. Time elapsed: 29.0298 min
# Processing text 1040. Time elapsed: 29.7854 min
# Processing text 1050. Time elapsed: 30.0104 min
# Processing text 1060. Time elapsed: 30.2246 min
# Processing text 1070. Time elapsed: 30.9688 min
# Processing text 1080. Time elapsed: 31.2032 min
# Processing text 1090. Time elapsed: 31.4452 min
# Processing text 1100. Time elapsed: 31.668 min
# Processing text 1110. Time elapsed: 31.9397 min
# Processing text 1120. Time elapsed: 32.1757 min
# Processing text 1130. Time elapsed: 32.924 min
# Processing text 1140. Time elapsed: 33.1466 min
# Processing text 1150. Time elapsed: 33.3788 min
#
# Time elapsed 33.3789 min

# %%
df_dev['gpt_pred'] = df_dev['text'].map( res )
df_dev['gpt_pred'].value_counts()
# Out:
# emotional                                                                                                                                                                                                                                                                                                                                                        600
# neutral                                                                                                                                                                                                                                                                                                                                                          577
# Yes, the category is humorous.                                                                                                                                                                                                                                                                                                                                     2
# As an AI language model, I do not have personal beliefs or emotions. I provide responses based on the input text and categorize them accordingly. Therefore, my response to the given text "Dear give us 20 min we are offering prayer" is "polite".                                                                                                               1
# Yes, I'm sure. The category is motivational/inspirational.                                                                                                                                                                                                                                                                                                         1
# Yes, I am sure. The category for the given text "Laptop ly k aa apna ... Jo dykhana hy dykhaoo." is commanding/authoritative.                                                                                                                                                                                                                                      1
# I apologize for my previous response. The text you provided is vulgar and offensive. As an AI language model, I cannot engage in such conversations. Please refrain from using such language in the future.                                                                                                                                                        1
# Yes, I'm sure. So, the category is sympathetic.                                                                                                                                                                                                                                                                                                                    1
# Yes, I'm sure. The text contains derogatory language about a particular race, so the category is inappropriate/derogatory.                                                                                                                                                                                                                                         1
# I apologize for the confusion. Based on the text, the category is unclear as there seems to be a typo or error in the text.                                                                                                                                                                                                                                        1
# I apologize for the mistake. The text "Nam nehad democracy se jaan churao" falls under the category of political.                                                                                                                                                                                                                                                  1
# I apologize for my previous response. As an AI language model, I should not have used such language. The appropriate category for the text would be "vulgar/offensive".                                                                                                                                                                                            1
# Yes, the category is positive.                                                                                                                                                                                                                                                                                                                                     1
# I apologize for the confusion. As an AI language model, I try my best to understand and categorize the text based on the context and language patterns. However, sometimes the text can be ambiguous or unclear, making it difficult to categorize. In this case, I am not sure about the category of the text as it seems incomplete and doesn't make sense.      1
# I apologize for my mistake. The category for the previous text should be offensive.                                                                                                                                                                                                                                                                                1
# Name: gpt_pred, dtype: int64

# %%
df_dev['gpt_pred_binary'] = df_dev['gpt_pred'].apply( lambda x: 0 if x=='neutral' else 1 )
df_dev['gpt_pred_binary'].value_counts()
# Out:
# 1    614
# 0    577
# Name: gpt_pred_binary, dtype: int64

# %%
y_dev      = df_dev['target'].values
y_dev_pred = df_dev['gpt_pred_binary'].values
print( classification_report( y_dev, y_dev_pred, digits=4 ) )
# Out:
#               precision    recall  f1-score   support
#
#            0     0.4714    0.7010    0.5637       388
#            1     0.8111    0.6202    0.7029       803
#
#     accuracy                         0.6465      1191
#    macro avg     0.6412    0.6606    0.6333      1191
# weighted avg     0.7004    0.6465    0.6576      1191

# %% [markdown]
# ## APPENDIX

# %% [markdown]
# ### Prompts and results (in reverse chronological order)

# %% [markdown]
# __CONCLUSIONS__:
# * The more examples the better. Even a few most similar examples are not as good as 100 examples

# %% [markdown]
# __Experiment 6__
# Same as experiment 3, but using only 10 semantically closest texts as examples instead of 100
# ```
#               precision    recall  f1-score   support
#
#            0     0.4714    0.7010    0.5637       388
#            1     0.8111    0.6202    0.7029       803
#
#     accuracy                         0.6465      1191
#    macro avg     0.6412    0.6606    0.6333      1191
# weighted avg     0.7004    0.6465    0.6576      1191
# ```

# %% [markdown]
# __Experiment 5__
# Same as experiment 3, but using only 25 semantically closest texts as examples instead of 100
# ```
#               precision    recall  f1-score   support
#
#            0     0.5191    0.6289    0.5688       388
#            1     0.8003    0.7186    0.7572       803
#
#     accuracy                         0.6893      1191
#    macro avg     0.6597    0.6737    0.6630      1191
# weighted avg     0.7087    0.6893    0.6958      1191
# ```
# _____

# %% [markdown]
# __Experiment 4__
# Same as experiment 3, but using only 50 semantically closest texts as examples instead of 100
# ```
#               precision    recall  f1-score   support
#
#            0     0.5583    0.5799    0.5689       388
#            1     0.7931    0.7783    0.7857       803
#
#     accuracy                         0.7137      1191
#    macro avg     0.6757    0.6791    0.6773      1191
# weighted avg     0.7166    0.7137    0.7151      1191
# ```
# _____

# %% [markdown]
# __Experiment 3__
# Did this instead of splitting training set into random chunks:
# * Get OpenAI embeddings for original bilingual texts in the training set and dev set
# * For each dev set text (its embedding), find 100 closest texts (embeddings) in the training set using the cosine similarity metric
# * Using the 100 closest texts as examples, create the messages object with alternating user (text) and assistant (category) chat utterances
# ```
#               precision    recall  f1-score   support
#
#            0     0.5948    0.5258    0.5581       388
#            1     0.7830    0.8269    0.8044       803
#
#     accuracy                         0.7288      1191
#    macro avg     0.6889    0.6763    0.6813      1191
# weighted avg     0.7217    0.7288    0.7241      1191
# ```
# _____

# %% [markdown]
# __Experiment 2__
# Split the training set into random non-stratified 62 chunks, each 100 examples long (this allows not to exceed the ChatGPT window size of 4096 tokens). Convert the 100 examples in each chunk into the messages object containing alternating user(text) and assistant (category) chat utterances. Iterate over chunks and dev set single examples and for each dev set example use the next message; the dev sety example is added as the next user utterance for few-shot learning - ChatGPT to respond with an assitant utterance containing the category.
# ```
#               precision    recall  f1-score   support
#
#            0     0.4895    0.4820    0.4857       388
#            1     0.7515    0.7572    0.7543       803
#
#     accuracy                         0.6675      1191
#    macro avg     0.6205    0.6196    0.6200      1191
# weighted avg     0.6662    0.6675    0.6668      1191
# ```
# _____

# %% [markdown]
# __Experiment 1__
# Split the training set into random non-stratified 46 chunks, each 135 examples long. Iteratively concatenate the 135 examples in each chunk as "Text: {text}\nCategory: {category}\n#####..." Iterate over chunks and dev set single examples and for each dev set example use the next concatenated chunk for few-shot learning.
# ```
#               precision    recall  f1-score   support
#
#            0     0.4723    0.5722    0.5175       388
#            1     0.7698    0.6912    0.7283       803
#
#     accuracy                         0.6524      1191
#    macro avg     0.6211    0.6317    0.6229      1191
# weighted avg     0.6729    0.6524    0.6597      1191
# ```
