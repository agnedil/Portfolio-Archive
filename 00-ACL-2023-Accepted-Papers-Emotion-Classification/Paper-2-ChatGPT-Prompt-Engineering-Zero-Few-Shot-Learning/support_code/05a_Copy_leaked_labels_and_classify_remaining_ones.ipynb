# %% [markdown]
# # Copy labels leaked from training set. Classify the rest using ChatGPT API

# %% [markdown]
# ## The Association for Computational Linguistics
# ## WASSA 2023 Shared Task on Multi-Label and Multi-Class Emotion Classification on Code-Mixed Text Messages
# See more details [here](https://codalab.lisn.upsaclay.fr/competitions/10864#learn_the_details)

# %%
import openai
import numpy as np
import pandas as pd
import sklearn
import re, os
import time
import zipfile, pickle
from typing import List
from copy import deepcopy
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, RidgeClassifier, RidgeClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, multilabel_confusion_matrix
from openai.embeddings_utils import cosine_similarity
from tqdm.autonotebook import tqdm
import random
import tiktoken
import backoff
tqdm.pandas()

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 400)
#os.path.join()
# Out:
# /var/folders/vb/p2r9brhx2335cwnww04p9w180000gn/T/ipykernel_44567/495498401.py:19: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
def num_tokens_from_messages(messages, model="gpt-3.5-turbo-0301"):
    '''Return number of tokens used in a list of messages for ChatGPT'''
    try:
        encoding = tiktoken.encoding_for_model(model)
    except KeyError:
        #print("Warning: model not found. Using cl100k_base encoding.")
        encoding = tiktoken.get_encoding("cl100k_base")
    if model == "gpt-3.5-turbo":
        #print("Warning: gpt-3.5-turbo may change over time. Returning num tokens assuming gpt-3.5-turbo-0301.")
        return num_tokens_from_messages(messages, model="gpt-3.5-turbo-0301")
    elif model == "gpt-4":
        #print("Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.")
        return num_tokens_from_messages(messages, model="gpt-4-0314")
    elif model == "gpt-3.5-turbo-0301":
        tokens_per_message = 4  # every message follows <|start|>{role/name}\n{content}<|end|>\n
        tokens_per_name = -1  # if there's a name, the role is omitted
    elif model == "gpt-4-0314":
        tokens_per_message = 3
        tokens_per_name = 1
    else:
        raise NotImplementedError(f"""num_tokens_from_messages() is not implemented for model {model}. See https://github.com/openai/openai-python/blob/main/chatml.md for information on how messages are converted to tokens.""")
    num_tokens = 0
    for message in messages:
        num_tokens += tokens_per_message
        for key, value in message.items():
            num_tokens += len(encoding.encode(value))
            if key == "name":
                num_tokens += tokens_per_name
    num_tokens += 3  # every reply is primed with <|start|>assistant<|message|>
    return num_tokens

# %%
random_state = 47

# %% [markdown]
# # Load and Prepare Data

# %%
file1    = 'data/mcec_train_translated.pkl'
df_train = pd.read_pickle(file1)

file2    = 'data/mcec_dev_translated.pkl'
df_dev   = pd.read_pickle(file2)

file3    = 'data/mcec_test_embedded.pkl'
df_test  = pd.read_pickle(file3)

file4    = 'data/sample_submission/predictions_MCEC.csv'
sample_submission = pd.read_csv(file4)

print(df_train.shape, df_dev.shape, df_test.shape, sample_submission.shape)
# Out:
# (9530, 5) (1191, 12) (1191, 2) (1191, 1)

# %%
# submission format
print( type(sample_submission) )
sample_submission.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Emotion
# 0    neutral
# 1    neutral
# 2  pessimism
# 3    disgust
# 4       fear

# %%
print(df_train['emotion'].value_counts(), '\n')
df_train.head()
# Out:
# neutral         3262
# trust           1118
# joy             1022
# optimism         880
# anticipation     832
# disgust          687
# sadness          486
# fear             453
# anger            226
# surprise         199
# love             187
# pessimism        178
# Name: emotion, dtype: int64
#                                                 text  emotion  \
# 0  Yes.I am in fyp lab cabin.but fyp presentation...  neutral
# 1           Yar insan ka bcha bn chawliyn na mar :p       joy
# 2  Terai uncle nai kahna hai kai ham nai to bahr ...  disgust
# 3                      Yr ajao I m cming in the club  neutral
# 4  Mje wese Nimra ahmad ka Qur'aan ki aayaat k ba...      joy
#
#                                        translated_hi  \
# 0  Yes.i am in fyp lab cabin.but fyp presentation...
# 1  Dude become a child of a human being, do not die.
# 2     Your Uncle Nai says that we had sent out money
# 3                     YR AJAO I'M Coming in the Club
# 4  Mje wes nimra ahmad ka qur'aan ki aayaat k bar...
#
#                                        translated_ur  \
# 0  Y. Um in Fap Lab Cabin. Butt Fap Presentations...
# 1                 Dude human beings do not die: P: P
# 2  Your Ankali says that we sent out money and wa...
# 3                           Yer organs were the club
# 4  Mje Wese Nimra Ahmad Ka Qur'aan Ki Aayaaat K B...
#
#                                        gpt_embedding
# 0  [-0.005477939732372761, -0.01738985814154148, ...
# 1  [0.0006696455529890954, -0.006965265609323978,...
# 2  [0.021171217784285545, -0.02109299972653389, 0...
# 3  [-0.010511564090847969, -0.02738134376704693, ...
# 4  [-0.0016743674641475081, -0.021855581551790237...

# %%
print(df_dev['emotion'].value_counts(), '\n')
df_dev.head()
# Out:
# neutral         388
# joy             131
# trust           125
# disgust         113
# optimism        110
# anticipation     94
# sadness          62
# fear             52
# surprise         35
# anger            35
# pessimism        29
# love             17
# Name: emotion, dtype: int64
#                                                 text    emotion  target  \
# 0                        Tension lene ki koi baat ni    neutral       1
# 1        Main ghar punch gya hun or ab spny laga hun    neutral       1
# 2            Nai mje nai mili mail..mene check ki ti  pessimism       0
# 3  Yr us din mai pura din bzy rahe vo mujy awne h...    disgust       0
# 4                Lakin wo abhe dar dar ka chalata ha       fear       0
#
#                                       gtp_translated  \
# 0                   There's no need to take tension.
# 1   I have reached home and now I am going to sleep.
# 2          I didn't receive any mail, I had checked.
# 3  That day, they were busy all day and not givin...
# 4                     But he still walks cautiously.
#
#                                        translated_hi  \
# 0                   There is nothing to take tension
# 1          I have gone home punch and now I am Sapni
# 2                Nai Maje Nai Mile Mail .. I checked
# 3  YR Us Din Mai Pura Din Bzy Rahe Vo Mujy Awne H...
# 4                     But it still moves at the rate
#
#                                        translated_ur  \
# 0                         Any talk of taking tangoes
# 1              I have gone home punch and now dreams
# 2                                Ni Ni Ni Mille Mail
# 3  Yr us din mai pura din bzy rahe vo mujy awne h...
# 4                              But Wu runs the cedar
#
#                                           text_clean  gpt_pred  gpt_pred_num  \
# 0                        Tension lene ki koi baat ni   neutral             1
# 1        Main ghar punch gya hun or ab spny laga hun   neutral             1
# 2          Nai mje nai mili mail .. mene check ki ti   neutral             1
# 3  Yr us din mai pura din bzy rahe vo mujy awne h...  negative             0
# 4                Lakin wo abhe dar dar ka chalata ha   neutral             1
#
#                                      gpt_translated2  \
# 0                          There's no need to worry.
# 1   I have reached home and now I am going to sleep.
# 2      I didn't receive any new mail. I had checked.
# 3  I was busy the whole day on that day, they wer...
# 4       But he still walks with fear and hesitation.
#
#                            gpt_translated2_corrected  \
# 0                          There's no need to worry.
# 1   I have reached home and now I am going to sleep.
# 2      I didn't receive any new mail. I had checked.
# 3  I was busy the whole day on that day, they wer...
# 4       But he still walks with fear and hesitation.
#
#                                        gpt_embedding
# 0  [-0.00021548081713262945, 0.005029499996453524...
# 1  [-0.0010164333507418633, -0.013282055966556072...
# 2  [-0.010691414587199688, -0.01292553823441267, ...
# 3  [0.009936108253896236, -0.016926730051636696, ...
# 4  [0.019262924790382385, -0.0011249196249991655,...

# %%
# light text cleaning (should I use clean regex for better accuracy?)
pad_punct    = re.compile('([^a-zA-Z ]+)')
multi_spaces = re.compile('\s{2,}')
#clean        = re.compile('[^a-zA-Z0-9,.?!\'\s]+')

def clean_text(s):
    s = s.replace('\n', ' ')
    s = pad_punct.sub(r' \1 ', s)
    #s = clean.sub(' ', s)
    s = multi_spaces.sub(' ', s)
    return s.strip()

df_train['text_clean'] = df_train['text'].apply( clean_text )
df_dev['text_clean']   = df_dev['text'].apply( clean_text )
df_test['text_clean']  = df_test['text'].apply( clean_text )

# %%
# 93 complete duplicates - can't reduce because this is a test set
print(df_test.shape)
temp1 = df_test[ df_test.duplicated(subset=['text_clean'], keep=False) ]
print(temp1.shape)
# Out:
# (1191, 3)
# (93, 3)

# %%
cols = ['text', 'text_clean', 'emotion', 'gpt_embedding',]
df_combined = pd.concat([df_train[cols], df_dev[cols]])
print(df_train.shape, df_dev.shape, df_combined.shape)
df_combined.head()
# Out:
# (9530, 6) (1191, 12) (10721, 4)
#                                                 text  \
# 0  Yes.I am in fyp lab cabin.but fyp presentation...
# 1           Yar insan ka bcha bn chawliyn na mar :p
# 2  Terai uncle nai kahna hai kai ham nai to bahr ...
# 3                      Yr ajao I m cming in the club
# 4  Mje wese Nimra ahmad ka Qur'aan ki aayaat k ba...
#
#                                           text_clean  emotion  \
# 0  Yes . I am in fyp lab cabin . but fyp presenta...  neutral
# 1           Yar insan ka bcha bn chawliyn na mar : p      joy
# 2  Terai uncle nai kahna hai kai ham nai to bahr ...  disgust
# 3                      Yr ajao I m cming in the club  neutral
# 4  Mje wese Nimra ahmad ka Qur ' aan ki aayaat k ...      joy
#
#                                        gpt_embedding
# 0  [-0.005477939732372761, -0.01738985814154148, ...
# 1  [0.0006696455529890954, -0.006965265609323978,...
# 2  [0.021171217784285545, -0.02109299972653389, 0...
# 3  [-0.010511564090847969, -0.02738134376704693, ...
# 4  [-0.0016743674641475081, -0.021855581551790237...

# %%
def transfer_label_to_test(row):
    candidates = df_combined[ df_combined['text_clean']==row['text_clean'] ]['emotion'].tolist()
    if len(candidates) == 0:
        pass
    elif len(set(candidates)) == 1:
        row['Emotion'] = candidates[0]
    else:
        print(f"Row #{row.name}: combined labels are {candidates}")
    return row


df_test['Emotion'] = np.nan
df_test = df_test.apply( transfer_label_to_test, axis=1 )

print(df_test.isna().sum())
df_test['Emotion'].value_counts()
# Out:
# text               0
# gpt_embedding      0
# text_clean         0
# Emotion          607
# dtype: int64
# neutral         194
# trust            72
# optimism         54
# disgust          51
# joy              51
# anticipation     43
# sadness          37
# fear             32
# pessimism        16
# anger            13
# surprise         11
# love             10
# Name: Emotion, dtype: int64

# %%
df_test.head()
# Out:
#                                           text  \
# 0      Razia bta rahe the but wo sure nahe the
# 1                  Me phr kuch parh hi lun :-P
# 2  Hoxtl life ma hm bht jald matur hO jaty hai
# 3                  Yar A4 me seminar ha a ja..
# 4                K.Quid e azam k 400 bnay hain
#
#                                        gpt_embedding  \
# 0  [0.00961806159466505, -0.009336333721876144, 0...
# 1  [0.004914113786071539, -0.011376334354281425, ...
# 2  [0.006094285752624273, -0.002856901613995433, ...
# 3  [-0.018210574984550476, -0.021075459197163582,...
# 4  [-0.0046786158345639706, -0.009765759110450745...
#
#                                     text_clean  Emotion
# 0      Razia bta rahe the but wo sure nahe the      NaN
# 1                 Me phr kuch parh hi lun :- P      NaN
# 2  Hoxtl life ma hm bht jald matur hO jaty hai     fear
# 3                Yar A 4 me seminar ha a ja ..  neutral
# 4              K . Quid e azam k 400 bnay hain  neutral

# %% [markdown]
# Overlap has already been used - no need to remove it from df_combined

# %%
file = 'data/df_test_with_leakedData_only.pkl'
df_test.to_pickle(file)

# %%
df_test[ df_test['Emotion'].isna() ].shape
# Out:
# (607, 4)

# %% [markdown]
# # Find 100 closest

# %%
# find top_n closest df_train/df_dev embeddings for each df_test embedding
def batch_cosine(embedding_, df, top_n=100):
    df['similarity'] = df['gpt_embedding'].apply(lambda x: cosine_similarity(x, embedding_))
    return df.sort_values(by='similarity', ascending=False).head(top_n)['text'].tolist()

df_combined_copy = df_combined.copy()
start = time.time()
res   = dict()
count = 0
for t, e in df_test[ df_test['Emotion'].isna() ][['text', 'gpt_embedding']].values:
    if t in res:
        continue
    res[ t ] = batch_cosine( e, df_combined_copy, top_n=100, )
    count += 1
    if count % 10 == 0:
        print(f'Processing text {count}. Time elapsed: {round((time.time()-start)/60, 4)} min')
        with open('data/res.pkl', 'wb') as f:
            pickle.dump(res, f, protocol=pickle.HIGHEST_PROTOCOL)
                        
elapsed = (time.time() - start)/60
print(f'\nTime elapsed {round(elapsed, 4)} min')
# Out:
# Processing text 10. Time elapsed: 0.5274 min
# Processing text 20. Time elapsed: 1.0547 min
# Processing text 30. Time elapsed: 1.5857 min
# Processing text 40. Time elapsed: 2.1133 min
# Processing text 50. Time elapsed: 2.6383 min
# Processing text 60. Time elapsed: 3.1685 min
# Processing text 70. Time elapsed: 3.6973 min
# Processing text 80. Time elapsed: 4.2252 min
# Processing text 90. Time elapsed: 4.7567 min
# Processing text 100. Time elapsed: 5.2912 min
# Processing text 110. Time elapsed: 5.9743 min
# Processing text 120. Time elapsed: 6.6496 min
# Processing text 130. Time elapsed: 7.2865 min
# Processing text 140. Time elapsed: 7.9241 min
# Processing text 150. Time elapsed: 8.5195 min
# Processing text 160. Time elapsed: 9.0946 min
# Processing text 170. Time elapsed: 9.6611 min
# Processing text 180. Time elapsed: 10.229 min
# Processing text 190. Time elapsed: 10.7761 min
# Processing text 200. Time elapsed: 11.3072 min
# Processing text 210. Time elapsed: 11.8384 min
# Processing text 220. Time elapsed: 12.3685 min
# Processing text 230. Time elapsed: 12.898 min
# Processing text 240. Time elapsed: 13.4277 min
# Processing text 250. Time elapsed: 13.9573 min
# Processing text 260. Time elapsed: 14.4865 min
# Processing text 270. Time elapsed: 15.0179 min
# Processing text 280. Time elapsed: 15.5462 min
# Processing text 290. Time elapsed: 16.0779 min
# Processing text 300. Time elapsed: 16.6069 min
# Processing text 310. Time elapsed: 17.1347 min
# Processing text 320. Time elapsed: 17.6677 min
# Processing text 330. Time elapsed: 18.1937 min
# Processing text 340. Time elapsed: 18.7437 min
# Processing text 350. Time elapsed: 19.357 min
# Processing text 360. Time elapsed: 19.8862 min
# Processing text 370. Time elapsed: 20.417 min
# Processing text 380. Time elapsed: 20.9464 min
# Processing text 390. Time elapsed: 21.4726 min
# Processing text 400. Time elapsed: 22.0033 min
# Processing text 410. Time elapsed: 22.532 min
# Processing text 420. Time elapsed: 23.0594 min
# Processing text 430. Time elapsed: 23.5874 min
# Processing text 440. Time elapsed: 24.117 min
# Processing text 450. Time elapsed: 24.6473 min
# Processing text 460. Time elapsed: 25.1786 min
# Processing text 470. Time elapsed: 25.7055 min
# Processing text 480. Time elapsed: 26.2319 min
# Processing text 490. Time elapsed: 26.7604 min
# Processing text 500. Time elapsed: 27.2859 min
# Processing text 510. Time elapsed: 27.8126 min
# Processing text 520. Time elapsed: 28.3438 min
# Processing text 530. Time elapsed: 28.8712 min
# Processing text 540. Time elapsed: 29.4002 min
# Processing text 550. Time elapsed: 29.9341 min
# Processing text 560. Time elapsed: 30.4662 min
# Processing text 570. Time elapsed: 30.9962 min
# Processing text 580. Time elapsed: 31.5262 min
#
# Time elapsed 31.8971 min

# %%
len(df_test[ df_test['Emotion'].isna() ]['text'].unique()), len(res)
# Out:
# (587, 587)

# %%
df_test['closest_texts'] = None
df_test['closest_texts'] = df_test['text'].apply( lambda x: res[x] if x in res else None )
print(df_test.isna().sum())

file = 'data/df_test_100_closest_GptEmbeddings.pkl'
df_test.to_pickle(file)
# Out:
# text               0
# gpt_embedding      0
# text_clean         0
# Emotion          607
# closest_texts    584
# dtype: int64

# %%
df_test.head(50)
# Out:
#                                                  text  \
# 0             Razia bta rahe the but wo sure nahe the
# 1                         Me phr kuch parh hi lun :-P
# 2         Hoxtl life ma hm bht jald matur hO jaty hai
# 3                         Yar A4 me seminar ha a ja..
# 4                       K.Quid e azam k 400 bnay hain
# 5    Hm sb b a jate nd aur b bare bnde b a jate! :-D
# 6   Yr apnay senior ka method ya hota ha k wo all ...
# 7           thek ha sir i will be at your office at 1
# 8   Hahahaha tuj ma agr itni wafa ha to tu he sab ...
# 9   Well you didnt told me before that the meeting...
# 10           Yr abu ne mana kr dya, tm log chale jana
# 11  abi soya utha hn yr rplyy na aye to banda call...
# 12  Menu ki pta dhaka lgate rhe us manhus start hi...
# 13  hawn naa...\nMain umt hun tw unka campus  duba...
# 14                      Paisai easy paisa sai aai gai
# 15  Yr bnda Atleast rat ko txt kr dta merey apney ...
# 16                     Yr das v itne dair ho gaye ha.
# 17                    Ghnty tk nai ati..to btaein mje
# 18                 Sania api plz bt krna dae. Na hme.
# 19                       Or do haftay bhi to rehna he
# 20                         Yhn sy ban nhi rhy license
# 21  Yar muja ya pochana tha laptop kis compny ka a...
# 22                           Mry lye kia ly kr ai ho?
# 23  Ok wo msg ma kr dunga.. Ap attndnc lga dena n ...
# 24  Oye yar kya kr rha ha, aj dophr ko kya khaya t...
# 25  Yar mje heart ka masala hai subha me ne cardio...
# 26  Plzz us k lye bhi dua karna k us ka army mein ...
# 27  Haha me aisi chezn ki tension nai leta :-P dkh...
# 28  Yar sir nai jo 2 bit or three bi ka grey code ...
# 29                       Han g bs Allah pak karam kre
# 30  Yr mne pkre hen tu ne krna he to half pe krle ...
# 31   Hm sb b a jate nd aur b bare bnde b a jate! :-D
# 32              Hafiz sahib me nai ja sakta jamat pe.
# 33  Me OS k research papers class website p upload...
# 34  Mariam vo walimy p pehnna hay...vo hostel se j...
# 35  Ok. Ager 12 bjay say pehlay free ho jain to mn...
# 36                  WO phir dosre sec k with parho ge
# 37                        han 2no ko ek e jga beaj do
# 38              Super duper result cha gai hoooooooo
# 39  Mere kal 2 clases h.12.30 khtam ho jaye ge.aur...
# 40   Han hgai wo b.\nBs aik masla hay.\nLogical hay.
# 41                    i know wht u mean..... :P :P :P
# 42  Humae to card dia hy lakin us Mae sirf walima ...
# 43  in case of shortage of memory must know how to...
# 44                         If you want today's that I
# 45            Yr han mra fsc ka result kal aya ha abe
# 46                             Nope .. koi kaam tha ?
# 47  Trent aa tu gya ha inshallha out kre ga pollar...
# 48  bs thk h.is lye mane khud pucha. bd ma ye na h...
# 49        Fung ki classes 30-A johar town mae hoon gi
#
#                                         gpt_embedding  \
# 0   [0.00961806159466505, -0.009336333721876144, 0...
# 1   [0.004914113786071539, -0.011376334354281425, ...
# 2   [0.006094285752624273, -0.002856901613995433, ...
# 3   [-0.018210574984550476, -0.021075459197163582,...
# 4   [-0.0046786158345639706, -0.009765759110450745...
# 5   [-0.009173348546028137, -0.0036938106641173363...
# 6   [0.012461582198739052, 0.004763346165418625, 0...
# 7   [-0.005030790343880653, -0.015968872234225273,...
# 8   [-0.003401822643354535, -0.008568023331463337,...
# 9   [-0.005642556585371494, -0.004453025758266449,...
# 10  [0.022901535034179688, -0.01324721984565258, -...
# 11  [-0.014637974090874195, -0.018663082271814346,...
# 12  [0.011292432434856892, -0.013326681219041348, ...
# 13  [-0.014636051841080189, -0.02131051756441593, ...
# 14  [0.006469042040407658, 0.010846740566194057, 0...
# 15  [0.001289149047806859, 0.0016061661299318075, ...
# 16  [-0.012117898091673851, -0.019422827288508415,...
# 17  [-0.01757991686463356, -0.010236240923404694, ...
# 18  [-0.00949001219123602, -0.013047930784523487, ...
# 19  [0.0023986701853573322, 0.0036331857554614544,...
# 20  [0.0029569766484200954, 0.0034017448779195547,...
# 21  [0.0021210378035902977, 0.0004604990826919675,...
# 22  [0.019194647669792175, -0.0009029482607729733,...
# 23  [-0.011079670861363411, 0.003995199222117662, ...
# 24  [0.01290382444858551, -0.025229576975107193, -...
# 25  [-0.007655789609998465, -0.017180783674120903,...
# 26  [-0.0011410063598304987, -0.009847152978181839...
# 27  [-0.014968418516218662, 0.0125942537561059, 0....
# 28  [-0.0032885826658457518, -0.007667210884392261...
# 29  [-0.0059815822169184685, -0.001097926637157797...
# 30  [0.01941920816898346, 0.0019471131963655353, -...
# 31  [-0.009173348546028137, -0.0036938106641173363...
# 32  [-0.031658537685871124, -0.015625184401869774,...
# 33  [-0.003514920361340046, 0.005498362705111504, ...
# 34  [-0.012656863778829575, -0.02635170705616474, ...
# 35  [-0.01767931506037712, -0.01609220914542675, -...
# 36  [-0.0008143687155097723, 0.0005062291747890413...
# 37  [-0.014345112256705761, 0.009338987991213799, ...
# 38  [-0.005238477606326342, 0.003549175104126334, ...
# 39  [-0.013449149206280708, 0.0012263027019798756,...
# 40  [-0.010955502279102802, 0.0023849387653172016,...
# 41  [-0.005461469758301973, -0.016501720994710922,...
# 42  [-0.004793952684849501, 0.0017937103984877467,...
# 43  [0.0010959416395053267, 0.0003760866529773921,...
# 44  [-0.03961332514882088, 0.025830620899796486, 0...
# 45  [-0.003237402532249689, 0.001442827982828021, ...
# 46  [0.01967829279601574, -0.017051933333277702, -...
# 47  [-0.010401813313364983, -0.00709244841709733, ...
# 48  [0.0008311858400702477, 0.008461182937026024, ...
# 49  [-0.006057010963559151, -0.003128551412373781,...
#
#                                            text_clean       Emotion  \
# 0             Razia bta rahe the but wo sure nahe the           NaN
# 1                        Me phr kuch parh hi lun :- P           NaN
# 2         Hoxtl life ma hm bht jald matur hO jaty hai          fear
# 3                       Yar A 4 me seminar ha a ja ..       neutral
# 4                     K . Quid e azam k 400 bnay hain       neutral
# 5   Hm sb b a jate nd aur b bare bnde b a jate ! :- D           NaN
# 6   Yr apnay senior ka method ya hota ha k wo all ...       neutral
# 7           thek ha sir i will be at your office at 1           NaN
# 8   Hahahaha tuj ma agr itni wafa ha to tu he sab ...           NaN
# 9   Well you didnt told me before that the meeting...           NaN
# 10          Yr abu ne mana kr dya , tm log chale jana          fear
# 11  abi soya utha hn yr rplyy na aye to banda call...           NaN
# 12  Menu ki pta dhaka lgate rhe us manhus start hi...       disgust
# 13  hawn naa ... Main umt hun tw unka campus dubai...       neutral
# 14                      Paisai easy paisa sai aai gai           NaN
# 15  Yr bnda Atleast rat ko txt kr dta merey apney ...          fear
# 16                    Yr das v itne dair ho gaye ha .       disgust
# 17                  Ghnty tk nai ati .. to btaein mje           NaN
# 18               Sania api plz bt krna dae . Na hme .         trust
# 19                       Or do haftay bhi to rehna he       neutral
# 20                         Yhn sy ban nhi rhy license       neutral
# 21  Yar muja ya pochana tha laptop kis compny ka a...         trust
# 22                          Mry lye kia ly kr ai ho ?  anticipation
# 23  Ok wo msg ma kr dunga .. Ap attndnc lga dena n...           NaN
# 24  Oye yar kya kr rha ha , aj dophr ko kya khaya ...           NaN
# 25  Yar mje heart ka masala hai subha me ne cardio...          fear
# 26  Plzz us k lye bhi dua karna k us ka army mein ...          fear
# 27  Haha me aisi chezn ki tension nai leta :- P dk...           NaN
# 28  Yar sir nai jo 2 bit or three bi ka grey code ...       neutral
# 29                       Han g bs Allah pak karam kre           NaN
# 30  Yr mne pkre hen tu ne krna he to half pe krle ...       neutral
# 31  Hm sb b a jate nd aur b bare bnde b a jate ! :- D           NaN
# 32             Hafiz sahib me nai ja sakta jamat pe .     pessimism
# 33  Me OS k research papers class website p upload...       neutral
# 34  Mariam vo walimy p pehnna hay ... vo hostel se...       neutral
# 35  Ok . Ager 12 bjay say pehlay free ho jain to m...           NaN
# 36                  WO phir dosre sec k with parho ge           NaN
# 37                       han 2 no ko ek e jga beaj do           NaN
# 38               Super duper result cha gai hoooooooo           NaN
# 39  Mere kal 2 clases h .12.30 khtam ho jaye ge . ...  anticipation
# 40   Han hgai wo b . Bs aik masla hay . Logical hay .           NaN
# 41                i know wht u mean ..... : P : P : P           NaN
# 42  Humae to card dia hy lakin us Mae sirf walima ...           NaN
# 43  in case of shortage of memory must know how to...       neutral
# 44                       If you want today ' s that I       neutral
# 45            Yr han mra fsc ka result kal aya ha abe       neutral
# 46                             Nope .. koi kaam tha ?           NaN
# 47  Trent aa tu gya ha inshallha out kre ga pollar...           NaN
# 48  bs thk h . is lye mane khud pucha . bd ma ye n...  anticipation
# 49       Fung ki classes 30- A johar town mae hoon gi           NaN
#
#                                         closest_texts
# 0   [Hn hn zaror ye raz hi rahe ga, Razia ne ma'am...
# 1   [I phne ke sheshkay lea ja raha ha :-P , Han m...
# 2                                                None
# 3                                                None
# 4                                                None
# 5   [Tu tnsn na le tje to kafi bnde churane aa jat...
# 6                                                None
# 7   [ok sir i will be there, Sir at what time i ca...
# 8   [Hahahah ab tu dost k liyee itna b nahi kr sak...
# 9   [I got load of work to do . Thats why i will t...
# 10                                               None
# 11  [Yr bnda reply hi kr deta ha, Yr bnda reply hi...
# 12                                               None
# 13                                               None
# 14  [Payment bhi easy paisai sai krni, Uni me easy...
# 15                                               None
# 16                                               None
# 17  [nai.. me tu ghussay me b is se aagy kuch nai ...
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23  [Okay alright ma msg phly apko fOrward krta hu...
# 24  [Yar tu aj yaha araha hai...!???, Yar tu aj ya...
# 25                                               None
# 26                                               None
# 27  [hahhahah nai me bna rhaa hn is liay kh ra :-P...
# 28                                               None
# 29  [Han a kr dhkun ga in sha Allah, Han g kya hal...
# 30                                               None
# 31  [Tu tnsn na le tje to kafi bnde churane aa jat...
# 32                                               None
# 33                                               None
# 34                                               None
# 35  [Hmmmmm. Ager barish ruki rahi to mn 9 bjay ja...
# 36  [Parhne ki koshishb kr raha hon., Hmm phr to d...
# 37  [Han wo keh rehe the aj 2 bje tk jama karwana ...
# 38  [Ha yaar us ka b acha result Aya the, Result k...
# 39                                               None
# 40  [Han yr ye masla rahay ga ab , Han kr lo waisy...
# 41  [No i know u r not kidding now :-(, tujy waqai...
# 42  [Han chlo hum kul bat krty hn mam se.., Ya hum...
# 43                                               None
# 44                                               None
# 45                                               None
# 46  [Haan yawr koi kam ni mila tha henna ? , Or ko...
# 47  [Yar duva kr pollard out hu jaye. Ameen., Yar ...
# 48                                               None
# 49  [Papa ko kaho 30-a phone kr kae puchae kae aj ...

# %% [markdown]
# # ChatGPT API: Few-Shot Classification

# %% [markdown]
# ## Helper functions

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")
model          = 'gpt-3.5-turbo'
labels_set     = { 'neutral', 'joy', 'trust', 'disgust', 'optimism', 'anticipation', 'sadness', 'fear',
                   'surprise', 'anger', 'pessimism', 'love', }
clean = re.compile(r'[^a-zA-Z ]+')
multi_spaces = re.compile('\s{2,}')
print(labels_set)
# Out:
# {'pessimism', 'fear', 'anticipation', 'optimism', 'surprise', 'neutral', 'love', 'sadness', 'disgust', 'anger', 'trust', 'joy'}

# %%
def verify_label(label_):
    '''
       Verify if label_ contains any of the categories
       from the predefined set of labels
    '''
    label_ = clean.sub(' ', label_)
    label_ = multi_spaces.sub(' ', label_).lower().split()
    res    = [i for i in label_ if i in labels_set]
    res    = list(set(res))
    return '/'.join(res) if res else None

# %%
def verify_num_tokens(model, messages):
    '''Check that there is enough tokens available for a ChatGPT repsonse'''
    num_tokens_tiktoken = num_tokens_from_messages(messages, model)
    if num_tokens_tiktoken > 4080:
        print(f'Number of tokens is {num_tokens_tiktoken} which exceeds 4080')        
        return False
    else:
        return True


@backoff.on_exception(backoff.expo, openai.error.RateLimitError, max_time=10)
def get_response(model, messages, temperature=0, max_tokens=None):
    '''Send request, return reponse'''
    response  = openai.ChatCompletion.create(
        model = model,
        messages = messages,
        temperature = temperature,        # range(0,2), the more the less deterministic / focused
        top_p = 1,                        # top probability mass, e.g. 0.1 = only tokens from top 10% proba mass
        n = 1,                            # number of chat completions
        #max_tokens = max_tokens,          # tokens to return
        stream = False,        
        stop=None,                        # sequence to stop generation (new line, end of text, etc.)
        )
    content = response['choices'][0]['message']['content'].strip()
    #num_tokens_api = response['usage']['prompt_tokens']
    return content

# %% [markdown]
# ## Approach 3: concatenate the closest few shot examples using the ChatGPT chat mode

# %%
model          = 'gpt-3.5-turbo'
embedding_type = 'gpt_embedding'
initial_prompt = 'Learn from the following examples of texts with assigned categories. ' +\
                 'Using this knowledge, select the most relevant category for the very last text below ' +\
                 'from the following list of predefined categories: neutral, joy, trust, disgust, optimism, ' +\
                 'anticipation, sadness, fear, surprise, anger, pessimism, love. ' +\
                 'Output only one most relevant category from the above list of predefined categories ' +\
                 'for the very last text below.'
print(initial_prompt)

# Using followup questions improves the reponse. but ChatGPT can change its mind too easily sometimes
followup1 = "Are you sure about that? If yes, output the same category, if no change the category, but make sure it's from the list of predefined categories"
print(followup1)
# Out:
# Learn from the following examples of texts with assigned categories. Using this knowledge, select the most relevant category for the very last text below from the following list of predefined categories: neutral, joy, trust, disgust, optimism, anticipation, sadness, fear, surprise, anger, pessimism, love. Output only one most relevant category from the above list of predefined categories for the very last text below.
# Are you sure about that? If yes, output the same category, if no change the category, but make sure it's from the list of predefined categories

# %%
# Using top_n closest embeddings, create ChatGPT messages object (alternating user (text)/assistant(category) Q&As)
def create_messages(df_, closest_texts, top_n=100 ):
    df_temp = df_[ df_['text'].isin(closest_texts[:top_n]) ]    
    text0, emotion0 = df_temp[['text', 'emotion']].values[0]
    messages = [ { "role": "system", "content": "You are a helpful text classifier.", },
                 { "role": "user", "content": initial_prompt + f' Text: {text0}', },
                 { "role": "assistant", "content": f'Category: {emotion0}', }
               ]    
    for text, emotion in df_temp[['text', 'emotion']].values[1:]:                  # emotion instead of target here
        messages += [
            { "role": "user", "content": f'Text: {text}', },
            { "role": "assistant", "content": f'Category: {emotion}', }
        ]
    while num_tokens_from_messages(messages) > 4000:
        messages = messages[:-2]
    return messages

# %%
def classify_text_few_shot3(text_, messages_, model):
    '''Classify text_ using prompt_ and ChatGPT API'''
    messages_ = deepcopy(messages_)
    messages_ += [
        { "role": "user", "content": f'Text: {text_}', },
    ]
    while num_tokens_from_messages(messages_) > 4000:
        messages_ = messages_[:-3] + [messages_[-1]]    # remove 1 user/assistant iteration before last just added
    #if not verify_num_tokens(model, messages_): return None
    label_    = get_response(model, messages_)
    old_label = label_
    label_    = verify_label(label_)        # get just the category if response is too long
        
    # if label not found in response text - second, extended chat
    if label_ is None:
        messages_ += [
            { "role": "assistant", "content": old_label, },
            { "role": "user", "content": followup1, }
            ]        
        label_    = get_response(model, messages_)
        old_label = label_
        label_    = verify_label(label_)        # get just the category if response is too long
            
    return label_ if label_ is not None else old_label

# %%
# how one messages object looks
c = df_test['closest_texts'].values[5]
print(c)
create_messages(df_combined, c, top_n=10)
# Out:
# ['Tu tnsn na le tje to kafi bnde churane aa jate! :-D  ', 'Uff etne se bt pa maun bnaya va ha janu na g :-P ', 'Hm tou agaye ab pahly kahti :-P ', 'Tay tsi zarur okhi krnii ay??? :-P ', 'I phne ke sheshkay lea ja raha ha :-P ', 'Hehehehe aj ux ke alaw beztie hoe :-P ', 'Hahaha bht buri ho :-O mene nai ana :-|', 'Puch to leti jane se pehle! Tu ne b mje lift nae krai! :-P ', 'Oh par ziada br hote ha na jani g. Pata ha ham dono ko ek doxra ke awax change krte ha :-D ', 'Dil karta ha uxa dkhtae he rhe :-P ', 'Hmmmmm aj maina date mare ux ka sath :-P ', 'Hmmmmm aj maina date mare ux ka sath :-P ', 'Janu aj a jao na milna :-D ', 'Janu aj a jao na milna :-D ', 'Tere khne k ilawa b krta rhta :P ', 'Me ny kab btaya tha py :O ', 'Me ny kab btaya tha py :O ', 'Me q pchy rhna c :-D ', 'Me bht bara item piece hn :-D', 'Ifsos hta ha. .aur bht hta hai :|', 'Hahaha bch k rehna :-P meri tarah bimar na hojana :-P', 'Yr jb meray 220 hjayen mje bta daina :-D ', 'Yr jb meray 220 hjayen mje bta daina :-D ', 'Yr jb meray 220 hjayen mje bta daina :-D ', 'Oye agr nahi ho rha to bata dy wo roz poch k sar khata ae:-P ', 'Hahahahahaha toh na clas mae aj akher kar di :-P ', 'Haha mjha pta hta me yahan hta? :-D', 'Em gud yrrrr\nMuju tu laga tha ap bhol hi gae hen ;-)', 'pass ho gyi ya wo b teri trh h ha :-P ', 'Irsa rply b kr de behn! Kal ana e tm ne???', 'hahaha. . .awlaaa h uni to aj ravi bni hvi :-D ', 'hahaha. . .awlaaa h uni to aj ravi bni hvi :-D ', 'Hahahhahahh very goood . .. mjy b batana me b krnga :-D :-P ', 'Ji shk e shk , aur buht shk :>', 'Ji shk e shk , aur buht shk :>', 'lol . . . me ny kabi galat b kha hai :-D ', 'Yeh me bilkul nai hunnn :-D ', 'Yeh me bilkul nai hunnn :-D ', 'Yeh me bilkul nai hunnn :-D ', 'Jumma mubarik :-P parh lea karo kbe tm bhe hehehe ', 'Haha bed per leta wa sb k prob solve kr ra :-P', 'Jumma mubarik :-P parh lea karo kbe tm bhe hehehe ', 'Yrr ek min mai dekh k btata ho :D', 'Yrr ek min mai dekh k btata ho :D', 'jani bechyn hr uni ma h hoti han :p  ', 'Nahi na tanz tu karna nahi ata :-P', 'Nahi na tanz tu karna nahi ata :-P', 'Nahi na tanz tu karna nahi ata :-P', 'Nahi na tanz tu karna nahi ata :-P', 'Haha hawn g zarur waiting k ap jub aen gy :) ', 'Nae g.hm bilkull nai boulay.hm nay kaha, aap zra bzy hein.free hou lein :-) ', 'Me to galti c keh betha aur to ', 'Me to galti c keh betha aur to ', 'Yr mere sth to aur b bura hta e agr ghlti mje rmote b mil jae to meri choti behn mere paprz hn cheekh cheekh kr e t.v bnd krwa deti e! ;-( ;-(,', 'Hehehehe shukar ha ma nai gyi :D', 'Oka :-P usa ab yeh snd kr :-P', 'Oh ho waisa hamari cl alaw ha :-P ', 'Zakie ae ga aftari ka bd phr chill mahol hoga :-P ', 'Tu tyri rakh agr aur chahiye howa to:-P ', 'Phr b yr. :-)koi tou faida ho na. ', 'Me ne b nhi dekhi :D', 'Me ne b nhi dekhi :D', 'Para hua hay..hani waghera ko nai diya :D', 'Ux na aj tak kbhe khud paisa dia b hain :-P ', 'Ux na aj tak kbhe khud paisa dia b hain :-P ', 'Nae shukr prsnal experience nae e abi tk :-P :-D bt banda ird gird b dekhta e sb kuch! Wese agr ye nakchire wali baat tu meri bari behn k samne kehti to wo tera sir pharr deti :-P :-D,', 'Nae ma zarur jao gi :D', 'Q khof kha gya hn.\nNi itni khata jani :P ', 'Hahaha bola to h ajao :-P ', 'Ni yar bt dua kro :-)', 'Dramae karta ha shoqa :-P ', 'hahhahah nai me bna rhaa hn is liay kh ra :-P ', 'Oh :-P bukhar hai yar :-|', 'Hmm.. Kheriat hay g sb :-)', 'Yar urdu urdu, mjay smjh ne lagti :-|', 'Yar urdu urdu, mjay smjh ne lagti :-|', 'Yar urdu urdu, mjay smjh ne lagti :-|', 'Han boht ziada. Ap b jldi jldi a jao. Ni to mehroom reh jao ge :-P', 'Ne yar awain bs ultay mazak krti main :-P:-D', 'Oh ja o0o kam kar apna pada na ho toh :-P ', 'ab kon c umer aa gai h apki??? :-D ', 'Wo b to tum ly k jati ho na sath aksr. ', 'Yr gr me beth jata to sara din b0r o jata ', 'Yr gr me beth jata to sara din b0r o jata ', 'Yr gr me beth jata to sara din b0r o jata ', 'Haha me? :-D me bht shareef hn :-D', 'Ne yar, main to kehti hu main buri hu.. ', 'Pta ne :-D yar abi sou ge to h ...
# [{'role': 'system', 'content': 'You are a helpful text classifier.'},
#  {'role': 'user',
#   'content': 'Learn from the following examples of texts with assigned categories. Using this knowledge, select the most relevant category for the very last text below from the following list of predefined categories: neutral, joy, trust, disgust, optimism, anticipation, sadness, fear, surprise, anger, pessimism, love. Output only one most relevant category from the above list of predefined categories for the very last text below. Text: Uff etne se bt pa maun bnaya va ha janu na g :-P '},
#  {'role': 'assistant', 'content': 'Category: joy'},
#  {'role': 'user', 'content': 'Text: Hahaha bht buri ho :-O mene nai ana :-|'},
#  {'role': 'assistant', 'content': 'Category: joy'},
#  {'role': 'user',
#   'content': 'Text: Oh par ziada br hote ha na jani g. Pata ha ham dono ko ek doxra ke awax change krte ha :-D '},
#  {'role': 'assistant', 'content': 'Category: anticipation'},
#  {'role': 'user',
#   'content': 'Text: Puch to leti jane se pehle! Tu ne b mje lift nae krai! :-P '},
#  {'role': 'assistant', 'content': 'Category: joy'},
#  {'role': 'user', 'content': 'Text: I phne ke sheshkay lea ja raha ha :-P '},
#  {'role': 'assistant', 'content': 'Category: joy'},
#  {'role': 'user',
#   'content': 'Text: Tu tnsn na le tje to kafi bnde churane aa jate! :-D  '},
#  {'role': 'assistant', 'content': 'Category: anticipation'},
#  {'role': 'user', 'content': 'Text: Hehehehe aj ux ke alaw beztie hoe :-P '},
#  {'role': 'assistant', 'content': 'Category: joy'},
#  {'role': 'user', 'content': 'Text: Dil karta ha uxa dkhtae he rhe :-P '},
#  {'role': 'assistant', 'content': 'Category: love'},
#  {'role': 'user', 'content': 'Text: Hm tou agaye ab pahly kahti :-P '},
#  {'role': 'assistant', 'content': 'Category: joy'},
#  {'role': 'user', 'content': 'Text: Tay tsi zarur okhi krnii ay??? :-P '},
#  {'role': 'assistant', 'content': 'Category: joy'}]

# %%
# this simple iteration is faster than pandas df with tqdm
model = 'gpt-3.5-turbo'
start = time.time()
#res   = dict()
count = 0
for t, closest in df_test[ df_test['Emotion'].isna() ][['text', 'closest_texts']].values:
    if t in res:
        continue
    messages = create_messages(df_combined, closest, top_n=100)
    try:
        res[ t ] = classify_text_few_shot3(t, messages, model)
    except openai.error.RateLimitError:
        print(f'\nText: {t}.\nRate limit error\n')
    except Exception as e:
        print(f'\nText: {t}\nError: {e}\n')
                
    count += 1    
    if count % 10 == 0:
        print(f'Processing text {count}. Time elapsed: {round((time.time()-start)/60, 4)} min')
        with open('data/res.pkl', 'wb') as f:
            pickle.dump(res, f, protocol=pickle.HIGHEST_PROTOCOL)
                        
        
elapsed = (time.time() - start)/60
print(f'\nTime elapsed {round(elapsed, 4)} min')
#file = 'data/res.pkl'
#with open(file, 'rb') as f:
#    res2 = pickle.load(handle)
# Out:
# Time elapsed 0.0273 min

# %%
len(df_test[ df_test['Emotion'].isna() ]['text'].unique()), len(res)
# Out:
# (587, 587)

# %% [markdown]
# #### If one label is the output: classify_text_few_shot3()

# %%
df_test.head(50)
# Out:
#                                                  text  \
# 0             Razia bta rahe the but wo sure nahe the
# 1                         Me phr kuch parh hi lun :-P
# 2         Hoxtl life ma hm bht jald matur hO jaty hai
# 3                         Yar A4 me seminar ha a ja..
# 4                       K.Quid e azam k 400 bnay hain
# 5    Hm sb b a jate nd aur b bare bnde b a jate! :-D
# 6   Yr apnay senior ka method ya hota ha k wo all ...
# 7           thek ha sir i will be at your office at 1
# 8   Hahahaha tuj ma agr itni wafa ha to tu he sab ...
# 9   Well you didnt told me before that the meeting...
# 10           Yr abu ne mana kr dya, tm log chale jana
# 11  abi soya utha hn yr rplyy na aye to banda call...
# 12  Menu ki pta dhaka lgate rhe us manhus start hi...
# 13  hawn naa...\nMain umt hun tw unka campus  duba...
# 14                      Paisai easy paisa sai aai gai
# 15  Yr bnda Atleast rat ko txt kr dta merey apney ...
# 16                     Yr das v itne dair ho gaye ha.
# 17                    Ghnty tk nai ati..to btaein mje
# 18                 Sania api plz bt krna dae. Na hme.
# 19                       Or do haftay bhi to rehna he
# 20                         Yhn sy ban nhi rhy license
# 21  Yar muja ya pochana tha laptop kis compny ka a...
# 22                           Mry lye kia ly kr ai ho?
# 23  Ok wo msg ma kr dunga.. Ap attndnc lga dena n ...
# 24  Oye yar kya kr rha ha, aj dophr ko kya khaya t...
# 25  Yar mje heart ka masala hai subha me ne cardio...
# 26  Plzz us k lye bhi dua karna k us ka army mein ...
# 27  Haha me aisi chezn ki tension nai leta :-P dkh...
# 28  Yar sir nai jo 2 bit or three bi ka grey code ...
# 29                       Han g bs Allah pak karam kre
# 30  Yr mne pkre hen tu ne krna he to half pe krle ...
# 31   Hm sb b a jate nd aur b bare bnde b a jate! :-D
# 32              Hafiz sahib me nai ja sakta jamat pe.
# 33  Me OS k research papers class website p upload...
# 34  Mariam vo walimy p pehnna hay...vo hostel se j...
# 35  Ok. Ager 12 bjay say pehlay free ho jain to mn...
# 36                  WO phir dosre sec k with parho ge
# 37                        han 2no ko ek e jga beaj do
# 38              Super duper result cha gai hoooooooo
# 39  Mere kal 2 clases h.12.30 khtam ho jaye ge.aur...
# 40   Han hgai wo b.\nBs aik masla hay.\nLogical hay.
# 41                    i know wht u mean..... :P :P :P
# 42  Humae to card dia hy lakin us Mae sirf walima ...
# 43  in case of shortage of memory must know how to...
# 44                         If you want today's that I
# 45            Yr han mra fsc ka result kal aya ha abe
# 46                             Nope .. koi kaam tha ?
# 47  Trent aa tu gya ha inshallha out kre ga pollar...
# 48  bs thk h.is lye mane khud pucha. bd ma ye na h...
# 49        Fung ki classes 30-A johar town mae hoon gi
#
#                                         gpt_embedding  \
# 0   [0.00961806159466505, -0.009336333721876144, 0...
# 1   [0.004914113786071539, -0.011376334354281425, ...
# 2   [0.006094285752624273, -0.002856901613995433, ...
# 3   [-0.018210574984550476, -0.021075459197163582,...
# 4   [-0.0046786158345639706, -0.009765759110450745...
# 5   [-0.009173348546028137, -0.0036938106641173363...
# 6   [0.012461582198739052, 0.004763346165418625, 0...
# 7   [-0.005030790343880653, -0.015968872234225273,...
# 8   [-0.003401822643354535, -0.008568023331463337,...
# 9   [-0.005642556585371494, -0.004453025758266449,...
# 10  [0.022901535034179688, -0.01324721984565258, -...
# 11  [-0.014637974090874195, -0.018663082271814346,...
# 12  [0.011292432434856892, -0.013326681219041348, ...
# 13  [-0.014636051841080189, -0.02131051756441593, ...
# 14  [0.006469042040407658, 0.010846740566194057, 0...
# 15  [0.001289149047806859, 0.0016061661299318075, ...
# 16  [-0.012117898091673851, -0.019422827288508415,...
# 17  [-0.01757991686463356, -0.010236240923404694, ...
# 18  [-0.00949001219123602, -0.013047930784523487, ...
# 19  [0.0023986701853573322, 0.0036331857554614544,...
# 20  [0.0029569766484200954, 0.0034017448779195547,...
# 21  [0.0021210378035902977, 0.0004604990826919675,...
# 22  [0.019194647669792175, -0.0009029482607729733,...
# 23  [-0.011079670861363411, 0.003995199222117662, ...
# 24  [0.01290382444858551, -0.025229576975107193, -...
# 25  [-0.007655789609998465, -0.017180783674120903,...
# 26  [-0.0011410063598304987, -0.009847152978181839...
# 27  [-0.014968418516218662, 0.0125942537561059, 0....
# 28  [-0.0032885826658457518, -0.007667210884392261...
# 29  [-0.0059815822169184685, -0.001097926637157797...
# 30  [0.01941920816898346, 0.0019471131963655353, -...
# 31  [-0.009173348546028137, -0.0036938106641173363...
# 32  [-0.031658537685871124, -0.015625184401869774,...
# 33  [-0.003514920361340046, 0.005498362705111504, ...
# 34  [-0.012656863778829575, -0.02635170705616474, ...
# 35  [-0.01767931506037712, -0.01609220914542675, -...
# 36  [-0.0008143687155097723, 0.0005062291747890413...
# 37  [-0.014345112256705761, 0.009338987991213799, ...
# 38  [-0.005238477606326342, 0.003549175104126334, ...
# 39  [-0.013449149206280708, 0.0012263027019798756,...
# 40  [-0.010955502279102802, 0.0023849387653172016,...
# 41  [-0.005461469758301973, -0.016501720994710922,...
# 42  [-0.004793952684849501, 0.0017937103984877467,...
# 43  [0.0010959416395053267, 0.0003760866529773921,...
# 44  [-0.03961332514882088, 0.025830620899796486, 0...
# 45  [-0.003237402532249689, 0.001442827982828021, ...
# 46  [0.01967829279601574, -0.017051933333277702, -...
# 47  [-0.010401813313364983, -0.00709244841709733, ...
# 48  [0.0008311858400702477, 0.008461182937026024, ...
# 49  [-0.006057010963559151, -0.003128551412373781,...
#
#                                            text_clean       Emotion  \
# 0             Razia bta rahe the but wo sure nahe the           NaN
# 1                        Me phr kuch parh hi lun :- P           NaN
# 2         Hoxtl life ma hm bht jald matur hO jaty hai          fear
# 3                       Yar A 4 me seminar ha a ja ..       neutral
# 4                     K . Quid e azam k 400 bnay hain       neutral
# 5   Hm sb b a jate nd aur b bare bnde b a jate ! :- D           NaN
# 6   Yr apnay senior ka method ya hota ha k wo all ...       neutral
# 7           thek ha sir i will be at your office at 1           NaN
# 8   Hahahaha tuj ma agr itni wafa ha to tu he sab ...           NaN
# 9   Well you didnt told me before that the meeting...           NaN
# 10          Yr abu ne mana kr dya , tm log chale jana          fear
# 11  abi soya utha hn yr rplyy na aye to banda call...           NaN
# 12  Menu ki pta dhaka lgate rhe us manhus start hi...       disgust
# 13  hawn naa ... Main umt hun tw unka campus dubai...       neutral
# 14                      Paisai easy paisa sai aai gai           NaN
# 15  Yr bnda Atleast rat ko txt kr dta merey apney ...          fear
# 16                    Yr das v itne dair ho gaye ha .       disgust
# 17                  Ghnty tk nai ati .. to btaein mje           NaN
# 18               Sania api plz bt krna dae . Na hme .         trust
# 19                       Or do haftay bhi to rehna he       neutral
# 20                         Yhn sy ban nhi rhy license       neutral
# 21  Yar muja ya pochana tha laptop kis compny ka a...         trust
# 22                          Mry lye kia ly kr ai ho ?  anticipation
# 23  Ok wo msg ma kr dunga .. Ap attndnc lga dena n...           NaN
# 24  Oye yar kya kr rha ha , aj dophr ko kya khaya ...           NaN
# 25  Yar mje heart ka masala hai subha me ne cardio...          fear
# 26  Plzz us k lye bhi dua karna k us ka army mein ...          fear
# 27  Haha me aisi chezn ki tension nai leta :- P dk...           NaN
# 28  Yar sir nai jo 2 bit or three bi ka grey code ...       neutral
# 29                       Han g bs Allah pak karam kre           NaN
# 30  Yr mne pkre hen tu ne krna he to half pe krle ...       neutral
# 31  Hm sb b a jate nd aur b bare bnde b a jate ! :- D           NaN
# 32             Hafiz sahib me nai ja sakta jamat pe .     pessimism
# 33  Me OS k research papers class website p upload...       neutral
# 34  Mariam vo walimy p pehnna hay ... vo hostel se...       neutral
# 35  Ok . Ager 12 bjay say pehlay free ho jain to m...           NaN
# 36                  WO phir dosre sec k with parho ge           NaN
# 37                       han 2 no ko ek e jga beaj do           NaN
# 38               Super duper result cha gai hoooooooo           NaN
# 39  Mere kal 2 clases h .12.30 khtam ho jaye ge . ...  anticipation
# 40   Han hgai wo b . Bs aik masla hay . Logical hay .           NaN
# 41                i know wht u mean ..... : P : P : P           NaN
# 42  Humae to card dia hy lakin us Mae sirf walima ...           NaN
# 43  in case of shortage of memory must know how to...       neutral
# 44                       If you want today ' s that I       neutral
# 45            Yr han mra fsc ka result kal aya ha abe       neutral
# 46                             Nope .. koi kaam tha ?           NaN
# 47  Trent aa tu gya ha inshallha out kre ga pollar...           NaN
# 48  bs thk h . is lye mane khud pucha . bd ma ye n...  anticipation
# 49       Fung ki classes 30- A johar town mae hoon gi           NaN
#
#                                         closest_texts
# 0   [Hn hn zaror ye raz hi rahe ga, Razia ne ma'am...
# 1   [I phne ke sheshkay lea ja raha ha :-P , Han m...
# 2                                                None
# 3                                                None
# 4                                                None
# 5   [Tu tnsn na le tje to kafi bnde churane aa jat...
# 6                                                None
# 7   [ok sir i will be there, Sir at what time i ca...
# 8   [Hahahah ab tu dost k liyee itna b nahi kr sak...
# 9   [I got load of work to do . Thats why i will t...
# 10                                               None
# 11  [Yr bnda reply hi kr deta ha, Yr bnda reply hi...
# 12                                               None
# 13                                               None
# 14  [Payment bhi easy paisai sai krni, Uni me easy...
# 15                                               None
# 16                                               None
# 17  [nai.. me tu ghussay me b is se aagy kuch nai ...
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23  [Okay alright ma msg phly apko fOrward krta hu...
# 24  [Yar tu aj yaha araha hai...!???, Yar tu aj ya...
# 25                                               None
# 26                                               None
# 27  [hahhahah nai me bna rhaa hn is liay kh ra :-P...
# 28                                               None
# 29  [Han a kr dhkun ga in sha Allah, Han g kya hal...
# 30                                               None
# 31  [Tu tnsn na le tje to kafi bnde churane aa jat...
# 32                                               None
# 33                                               None
# 34                                               None
# 35  [Hmmmmm. Ager barish ruki rahi to mn 9 bjay ja...
# 36  [Parhne ki koshishb kr raha hon., Hmm phr to d...
# 37  [Han wo keh rehe the aj 2 bje tk jama karwana ...
# 38  [Ha yaar us ka b acha result Aya the, Result k...
# 39                                               None
# 40  [Han yr ye masla rahay ga ab , Han kr lo waisy...
# 41  [No i know u r not kidding now :-(, tujy waqai...
# 42  [Han chlo hum kul bat krty hn mam se.., Ya hum...
# 43                                               None
# 44                                               None
# 45                                               None
# 46  [Haan yawr koi kam ni mila tha henna ? , Or ko...
# 47  [Yar duva kr pollard out hu jaye. Ameen., Yar ...
# 48                                               None
# 49  [Papa ko kaho 30-a phone kr kae puchae kae aj ...

# %%
# if one label is the output
def transfer_label(row):
    if not isinstance(row['Emotion'], str) and pd.isnull(row['Emotion']):
        row['Emotion'] = res.get(row['text'])
    return row
    
df_test = df_test.apply( transfer_label, axis=1 )
# Out:
# text                         0
# emotion                      0
# target                       0
# gtp_translated               0
# translated_hi                0
# translated_ur                0
# text_clean                   0
# gpt_pred                     0
# gpt_pred_num                 0
# gpt_translated2              0
# gpt_translated2_corrected    0
# gpt_embedding                0
# dtype: int64
# neutral     1019
# negative      88
# positive      84
# Name: gpt_pred, dtype: int64

# %%
print(df_test.isna().sum())
print(df_test['Emotion'].value_counts())
# Out:
# text               0
# gpt_embedding      0
# text_clean         0
# Emotion            0
# closest_texts    584
# dtype: int64
# neutral                     392
# trust                       164
# anticipation                124
# joy                         122
# optimism                    100
# disgust                      78
# sadness                      64
# fear                         46
# pessimism                    29
# anger                        28
# love                         23
# surprise                     18
# Category: disappointment      2
# Category: uncertainty         1
# Name: Emotion, dtype: int64

# %%
file = 'data/predictions_MCEC.csv'
df_test['Emotion'].to_csv( file, index=False, encoding='utf-8' )

# %% [markdown]
# The following corrections were made manually in the submission2_anedilko.csv file:
# * Row 187, Category: disappointment => anger
# * Row x, Category: disappointment => sadness
# * Row x, Category: uncertainty => pessimism
